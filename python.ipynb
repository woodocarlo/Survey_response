# %% [markdown]
# Renaming the files

# %%
import os

# Path to the folder containing the Excel files
folder_path = r'C:\Users\Satish\Downloads\Survey-responses'

# Get a list of all Excel files in the folder
excel_files = [f for f in os.listdir(folder_path) if f.endswith('.xlsx')]

# Rename each file
for i, file_name in enumerate(excel_files, start=1):
    new_name = f'survey-{i}.xlsx'
    old_file = os.path.join(folder_path, file_name)
    new_file = os.path.join(folder_path, new_name)
    os.rename(old_file, new_file)
    print(f'Renamed: {file_name} -> {new_name}')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[1], line 14
#      12 old_file = os.path.join(folder_path, file_name)
#      13 new_file = os.path.join(folder_path, new_name)
# ---> 14 os.rename(old_file, new_file)
#      15 print(f'Renamed: {file_name} -> {new_name}')
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\Satish\\Downloads\\Survey-responses\\Compact_Restructured_Survey2_Output.xlsx' -> 'C:\\Users\\Satish\\Downloads\\Survey-responses\\survey-1.xlsx'

# %% [markdown]
# Combining the different excel files into one

# %%
import pandas as pd
import glob
import os

# Function to process a single Excel file
def process_excel_file(file_path):
    # Load Excel file
    excel_file = pd.ExcelFile(file_path)
    
    # Check if 'Responses' sheet exists
    if 'Responses' in excel_file.sheet_names:
        # Process Sheet 1: Survey Responses
        df_survey = pd.read_excel(excel_file, 'Responses', header=0)
        
        # Determine Survey Type based on the 2nd question
        survey_type = None
        if df_survey.columns[1] == "What is your name?":
            survey_type = "Survey1"
        else:
            survey_type = "Survey2"
        
        # Load other sheets (if needed, currently not processed differently based on survey type)
        df_timings = pd.read_excel(excel_file, 'Time Taken', header=0)
        df_coordinates = pd.read_excel(excel_file, 'Mouse Movement', header=0)
        
        # Return the dataframes and survey type
        return df_survey, df_timings, df_coordinates, survey_type
    else:
        print(f"Worksheet 'Responses' not found in file: {file_path}")
        return None, None, None, None

# Function to combine all Excel files into two separate Excel files based on Survey Type
def combine_all_excel_files(directory_path):
    survey1_responses = []
    survey1_timings = []
    survey1_coordinates = []
    survey2_responses = []
    survey2_timings = []
    survey2_coordinates = []
    
    # Find all Excel files in the directory
    for file_path in glob.glob(directory_path + "/*.xlsx"):
        df_survey, df_timings, df_coordinates, survey_type = process_excel_file(file_path)
        
        # Append to the respective list if the worksheet was found
        if df_survey is not None:
            if survey_type == "Survey1":
                survey1_responses.append(df_survey)
                survey1_timings.append(df_timings)
                survey1_coordinates.append(df_coordinates)
            elif survey_type == "Survey2":
                survey2_responses.append(df_survey)
                survey2_timings.append(df_timings)
                survey2_coordinates.append(df_coordinates)
    
    # Combine all responses into a single dataframe for each survey type
    combined_survey1_responses = pd.concat(survey1_responses, ignore_index=True)
    combined_survey1_timings = pd.concat(survey1_timings, ignore_index=True)
    combined_survey1_coordinates = pd.concat(survey1_coordinates, ignore_index=True)
    combined_survey2_responses = pd.concat(survey2_responses, ignore_index=True)
    combined_survey2_timings = pd.concat(survey2_timings, ignore_index=True)
    combined_survey2_coordinates = pd.concat(survey2_coordinates, ignore_index=True)
    
    # Transform the Mouse Movement data to have time as columns and x, y coordinates as rows
    if 'Time' in combined_survey1_coordinates.columns and 'X' in combined_survey1_coordinates.columns and 'Y' in combined_survey1_coordinates.columns:
        combined_survey1_coordinates['Coordinates'] = combined_survey1_coordinates.apply(lambda row: f"{row['X']},{row['Y']}", axis=1)
        combined_survey1_coordinates = combined_survey1_coordinates.pivot(index=None, columns='Time', values='Coordinates')
    if 'Time' in combined_survey2_coordinates.columns and 'X' in combined_survey2_coordinates.columns and 'Y' in combined_survey2_coordinates.columns:
        combined_survey2_coordinates['Coordinates'] = combined_survey2_coordinates.apply(lambda row: f"{row['X']},{row['Y']}", axis=1)
        combined_survey2_coordinates = combined_survey2_coordinates.pivot(index=None, columns='Time', values='Coordinates')
    
    # Save the combined dataframes to new Excel files
    with pd.ExcelWriter("New_Combined_Survey1_Output.xlsx") as writer:
        combined_survey1_responses.to_excel(writer, sheet_name="Responses", index=False)
        combined_survey1_timings.to_excel(writer, sheet_name="Time Taken", index=False)
        combined_survey1_coordinates.to_excel(writer, sheet_name="Mouse Movement", index=False)
    
    with pd.ExcelWriter("New_Combined_Survey2_Output.xlsx") as writer:
        combined_survey2_responses.to_excel(writer, sheet_name="Responses", index=False)
        combined_survey2_timings.to_excel(writer, sheet_name="Time Taken", index=False)
        combined_survey2_coordinates.to_excel(writer, sheet_name="Mouse Movement", index=False)

# Usage
if __name__ == "__main__":
    directory_path = input("Enter the directory path containing your Excel files: ")
    combine_all_excel_files(directory_path)
    print("All files have been processed and combined into 'New_Combined_Survey1_Output.xlsx' and 'New_Combined_Survey2_Output.xlsx'.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 58
#      56 if __name__ == "__main__":
#      57     directory_path = input("Enter the directory path containing your Excel files: ")
# ---> 58     combine_all_excel_files(directory_path)
#      59     print("All files have been processed and combined into 'Combined_Survey_Output.xlsx'.")
#
# Cell In[7], line 49, in combine_all_excel_files(directory_path)
#      46         combined_data.append(combined_df)
#      48 # Concatenate all combined data into a single DataFrame
# ---> 49 final_combined_df = pd.concat(combined_data, ignore_index=True)
#      51 # Save the combined DataFrame to a new Excel file
#      52 with pd.ExcelWriter("Combined_Survey_Output.xlsx") as writer:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\reshape\concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\reshape\concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\reshape\concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %% [markdown]
# Combining the responses and time takes sheet of the combined excel

# %%
import pandas as pd
import json

# Load the Excel file
file_path = r'C:\Users\Satish\Downloads\Survey-responses\New_Combined_Survey2_Output.xlsx'
excel_file = pd.ExcelFile(file_path)

# Check if 'Responses' and 'Time Taken' sheets exist
if 'Responses' in excel_file.sheet_names and 'Time Taken' in excel_file.sheet_names:
    # Load the sheets
    df_responses = pd.read_excel(excel_file, 'Responses', header=0)
    df_timings = pd.read_excel(excel_file, 'Time Taken', header=0)
    
    # Combine the data into JSON format
    combined_data = []
    for i, row in df_responses.iterrows():
        combined_row = {}
        for col in df_responses.columns:
            # Match the corresponding column in the 'Time Taken' sheet
            timing_col = f"Q{df_responses.columns.get_loc(col) + 1} (seconds)"
            combined_row[col] = json.dumps({
                "responses": row[col],
                "time taken": df_timings.at[i, timing_col] if timing_col in df_timings.columns else None
            })
        combined_data.append(combined_row)
    
    # Convert to DataFrame
    combined_df = pd.DataFrame(combined_data)
    
    # Save the combined DataFrame to a new Excel file
    combined_df.to_excel('Combined_Survey_Output.xlsx', index=False)
    print("Combined data has been saved to 'Combined_Survey_Output.xlsx'")
else:
    print("Worksheet 'Responses' or 'Time Taken' not found in the file.")
# Out:
# Combined data has been saved to 'Combined_Survey_Output.xlsx'

# %%
import pandas as pd
import json
import glob
import os

# Function to process a single Excel file
def process_excel_file(file_path):
    # Load Excel file
    excel_file = pd.ExcelFile(file_path)
    
    # Check if 'Mouse Movement' sheet exists and if B1 contains the specified header
    if 'Mouse Movement' in excel_file.sheet_names and 'Responses' in excel_file.sheet_names:
        df_responses = pd.read_excel(excel_file, 'Responses', header=0)
        if df_responses.columns[1] == "What do you think is the most exciting application of AI in today's world?":
            df_mouse_movement = pd.read_excel(excel_file, 'Mouse Movement', header=0)
            
            # Process the data into JSON format
            movement_list = []
            for i, row in df_mouse_movement.iterrows():
                for col in df_mouse_movement.columns:
                    if pd.notna(row[col]):
                        value = str(row[col])
                        if ',' in value:
                            time, coordinates = value.split(',')
                            movement_list.append({
                                "time": time.strip(),
                                "coordinates": coordinates.strip()
                            })
            
            # Convert the movement list to JSON format
            movement_json = json.dumps(movement_list)
            
            return movement_json
    else:
        print(f"Worksheet 'Mouse Movement' or 'Responses' not found in file: {file_path}")
        return None

# Function to combine all Excel files into one sheet in JSON format
def combine_all_excel_files(directory_path):
    combined_data = []
    
    # Find all Excel files in the directory
    for file_path in glob.glob(directory_path + "/*.xlsx"):
        movement_json = process_excel_file(file_path)
        
        # Append to the combined data if the worksheet was found
        if movement_json is not None:
            combined_data.append({
                "mouse_movement": movement_json
            })
    
    # Convert the combined data to a DataFrame
    final_combined_df = pd.DataFrame(combined_data)
    
    # Save the combined DataFrame to a new Excel file
    final_combined_df.to_excel('Mouse_Movement_Output.xlsx', index=False)
    print("Mouse movement data has been saved to 'Mouse_Movement_Output.xlsx'")

# Usage
if __name__ == "__main__":
    directory_path = r'C:\Users\Satish\Downloads\Survey-responses'
    combine_all_excel_files(directory_path)
    print("All files have been processed and combined into 'Mouse_Movement_Output.xlsx'.")
# Out:
# Worksheet 'Mouse Movement' or 'Responses' not found in file: C:\Users\Satish\Downloads\Survey-responses\Mouse_Movement_Output.xlsx
# Mouse movement data has been saved to 'Mouse_Movement_Output.xlsx'
# All files have been processed and combined into 'Mouse_Movement_Output.xlsx'.

# %% [markdown]
# Combinging the mouse movement

# %%
import pandas as pd
import json
import glob
import os

# Function to process a single Excel file
def process_excel_file(file_path):
    # Load Excel file
    excel_file = pd.ExcelFile(file_path)
    
    # Check if 'Mouse Movement' sheet exists and if B1 contains the specified header
    if 'Mouse Movement' in excel_file.sheet_names and 'Responses' in excel_file.sheet_names:
        df_responses = pd.read_excel(excel_file, 'Responses', header=0)
        if df_responses.columns[1] == "What do you think is the most exciting application of AI in today's world?":
            df_mouse_movement = pd.read_excel(excel_file, 'Mouse Movement', header=0)
            
            # Process the data into JSON format
            movement_list = []
            for _, row in df_mouse_movement.iterrows():
                if pd.notna(row['Elapsed Time (seconds)']) and pd.notna(row['X-Y Coordinate']):
                    time = str(row['Elapsed Time (seconds)']).strip()
                    coordinates = str(row['X-Y Coordinate']).strip()
                    movement_list.append({
                        "time": time,
                        "coordinates": coordinates
                    })
            
            # Convert the movement list to JSON format
            movement_json = json.dumps(movement_list)
            
            return movement_json
    else:
        print(f"Worksheet 'Mouse Movement' or 'Responses' not found in file: {file_path}")
        return None

# Function to combine all Excel files into one sheet in JSON format
def combine_all_excel_files(directory_path):
    combined_data = []
    
    # Find all Excel files in the directory
    for file_path in glob.glob(directory_path + "/*.xlsx"):
        movement_json = process_excel_file(file_path)
        
        # Append to the combined data if the worksheet was found
        if movement_json is not None:
            combined_data.append({
                "mouse_movement": movement_json
            })
    
    # Convert the combined data to a DataFrame
    final_combined_df = pd.DataFrame(combined_data)
    
    # Save the combined DataFrame to a new Excel file
    final_combined_df.to_excel('Mouse_Movement_Output.xlsx', index=False)
    print("Mouse movement data has been saved to 'Mouse_Movement_Output.xlsx'")

# Usage
if __name__ == "__main__":
    directory_path = r'C:\Users\Satish\Downloads\Survey-responses'
    combine_all_excel_files(directory_path)
    print("All files have been processed and combined into 'Mouse_Movement_Output.xlsx'.")
# Out:
# Worksheet 'Mouse Movement' or 'Responses' not found in file: C:\Users\Satish\Downloads\Survey-responses\Mouse_Movement_Output.xlsx
# Mouse movement data has been saved to 'Mouse_Movement_Output.xlsx'
# All files have been processed and combined into 'Mouse_Movement_Output.xlsx'.

# %% [markdown]
# Converting mouse mouvement to avg velocity

# %%
import pandas as pd
import json
import numpy as np

# Load the dataset
file_path = r'C:\Users\Satish\Downloads\Survey-responses\Mouse_Movement_Output.xlsx'
df = pd.read_excel(file_path)

# Function to calculate the number of pauses (stationary positions)
def calculate_pauses(row, threshold=5, stationary_time=2):
    try:
        # Parse the JSON string from the mouse_movement column
        movements = json.loads(row)
        
        # Check if the data is valid (should be a list of objects)
        if not isinstance(movements, list) or len(movements) < 2:
            return 0
        
        # Initialize variables to count pauses
        pauses = 0
        consecutive_stationary_count = 0
        
        # Loop through consecutive points to detect pauses
        for i in range(1, len(movements)):
            t1 = float(movements[i-1]['time'])
            t2 = float(movements[i]['time'])
            x1, y1 = map(int, movements[i-1]['coordinates'].split(','))
            x2, y2 = map(int, movements[i]['coordinates'].split(','))
            
            # Calculate the distance between the points
            distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2)
            
            # If the distance is below the threshold, it's considered a stationary point
            if distance < threshold:
                consecutive_stationary_count += 1
            else:
                if consecutive_stationary_count >= stationary_time:
                    pauses += 1  # Considered a pause
                consecutive_stationary_count = 0
        
        # Check for a pause at the end of the movements
        if consecutive_stationary_count >= stationary_time:
            pauses += 1
        
        return pauses
    
    except json.JSONDecodeError as e:
        # In case of a JSON decoding error, log the issue
        print(f"JSONDecodeError: {e} in row {row}")
        return 0
    except Exception as e:
        # Handle any other exceptions (e.g., invalid data)
        print(f"Error: {e} in row {row}")
        return 0

# Step 2: Apply the calculation to each row in the dataframe
df['num_pauses'] = df['mouse_movement'].apply(calculate_pauses)

# Step 3: Save the results to a new Excel file
output_path = r'C:\Users\Satish\Downloads\Survey-responses\Mouse_Movement_Output_with_num_pauses.xlsx'
df.to_excel(output_path, index=False)

print(f'File saved to {output_path}')
# Out:
# JSONDecodeError: Unterminated string starting at: line 1 column 32761 (char 32760) in row [{"time": "0.02", "coordinates": "136,25"}, {"time": "0.03", "coordinates": "154,48"}, {"time": "0.04", "coordinates": "182,84"}, {"time": "0.06", "coordinates": "205,115"}, {"time": "0.08", "coordinates": "234,156"}, {"time": "0.09", "coordinates": "241,168"}, {"time": "0.12", "coordinates": "260,192"}, {"time": "0.13", "coordinates": "260,193"}, {"time": "0.14", "coordinates": "260,194"}, {"time": "0.16", "coordinates": "256,194"}, {"time": "0.17", "coordinates": "249,194"}, {"time": "0.19", "coordinates": "238,192"}, {"time": "0.21", "coordinates": "229,192"}, {"time": "0.66", "coordinates": "236,195"}, {"time": "0.66", "coordinates": "246,199"}, {"time": "0.68", "coordinates": "257,204"}, {"time": "0.69", "coordinates": "289,222"}, {"time": "0.71", "coordinates": "318,237"}, {"time": "0.72", "coordinates": "325,240"}, {"time": "0.74", "coordinates": "343,248"}, {"time": "0.76", "coordinates": "352,252"}, {"time": "0.78", "coordinates": "361,255"}, {"time": "0.79", "coordinates": "365,256"}, {"time": "0.81", "coordinates": "370,257"}, {"time": "0.83", "coordinates": "372,258"}, {"time": "0.84", "coordinates": "373,258"}, {"time": "0.86", "coordinates": "373,257"}, {"time": "0.88", "coordinates": "373,256"}, {"time": "0.89", "coordinates": "373,255"}, {"time": "0.91", "coordinates": "372,253"}, {"time": "1.5", "coordinates": "376,252"}, {"time": "1.51", "coordinates": "383,251"}, {"time": "1.52", "coordinates": "406,244"}, {"time": "1.54", "coordinates": "419,240"}, {"time": "1.56", "coordinates": "431,238"}, {"time": "1.57", "coordinates": "440,236"}, {"time": "1.59", "coordinates": "444,235"}, {"time": "1.61", "coordinates": "448,234"}, {"time": "1.63", "coordinates": "451,233"}, {"time": "1.64", "coordinates": "452,232"}, {"time": "1.66", "coordinates": "453,232"}, {"time": "1.68", "coordinates": "455,232"}, {"time": "1.69", "coordinates": "456,232"}, {"time": "1.72", "coordinates": "457,232"}, {"time": "1.82", "coordinates": "457,231"}, {"time": "1.83", "coordinates": "458,231"}, {"time": "1.85", "coordinates": "458,230"}, {"time": "1.86", "coordinates": "459,230"}, {"time": "1.88", "coordinates": "460,230"}, {"time": "1.9", "coordinates": "460,229"}, {"time": "1.91", "coordinates": "461,229"}, {"time": "1.93", "coordinates": "461,228"}, {"time": "1.98", "coordinates": "461,226"}, {"time": "1.99", "coordinates": "461,225"}, {"time": "2.01", "coordinates": "461,224"}, {"time": "2.03", "coordinates": "460,222"}, {"time": "2.04", "coordinates": "460,221"}, {"time": "2.06", "coordinates": "460,220"}, {"time": "2.08", "coordinates": "460,219"}, {"time": "2.09", "coordinates": "460,218"}, {"time": "2.11", "coordinates": "460,217"}, {"time": "2.13", "coordinates": "460,216"}, {"time": "2.17", "coordinates": "460,215"}, {"time": "2.21", "coordinates": "460,214"}, {"time": "2.24", "coordinates": "460,213"}, {"time": "2.26", "coordinates": "460,212"}, {"time": "2.32", "coordinates": "460,211"}, {"time": "2.36", "coordinates": "460,209"}, {"time": "2.38", "coordinates": "460,208"}, {"time": "2.39", "coordinates": "460,206"}, {"time": "2.41", "coordinates": "460,204"}, {"time": "2.42", "coordinates": "461,201"}, {"time": "2.44", "coordinates": "461,199"}, {"time": "2.46", "coordinates": "461,195"}, {"time": "2.48", "coordinates": "461,192"}, {"time": "2.49", "coordinates": "461,189"}, {"time": "2.51", "coordinates": "461,182"}, {"time": "2.52", "coordinates": "460,176"}, {"time": "2.54", "coordinates": "460,169"}, {"time": "2.56", "coordinates": "459,161"}, {"time": "2.58", "coordinates": "458,159"}, {"time": "2.59", "coordinates": "457,156"}, {"time": "2.61", "coordinates": "457,155"}, {"time": "2.63", "coordinates": "456,153"}, {"time": "2.65", "coordinates": "455,153"}, {"time": "2.69", "coordinates": "454,153"}, {"time": "2.71", "coordinates": "453,154"}, {"time": "2.73", "coordinates": "453,155"}, {"time": "2.74", "coordinates": "452,156"} ...
# JSONDecodeError: Unterminated string starting at: line 1 column 32765 (char 32764) in row [{"time": "3.67", "coordinates": "279,253"}, {"time": "3.68", "coordinates": "298,248"}, {"time": "3.69", "coordinates": "327,240"}, {"time": "3.71", "coordinates": "359,236"}, {"time": "3.73", "coordinates": "376,234"}, {"time": "3.75", "coordinates": "397,230"}, {"time": "3.76", "coordinates": "408,228"}, {"time": "3.78", "coordinates": "419,222"}, {"time": "3.8", "coordinates": "431,212"}, {"time": "3.81", "coordinates": "440,205"}, {"time": "3.83", "coordinates": "447,197"}, {"time": "3.85", "coordinates": "456,186"}, {"time": "3.86", "coordinates": "461,180"}, {"time": "3.88", "coordinates": "470,172"}, {"time": "3.89", "coordinates": "472,171"}, {"time": "3.91", "coordinates": "474,167"}, {"time": "3.93", "coordinates": "475,165"}, {"time": "3.94", "coordinates": "475,164"}, {"time": "3.97", "coordinates": "475,163"}, {"time": "4.01", "coordinates": "474,163"}, {"time": "4.04", "coordinates": "473,163"}, {"time": "4.04", "coordinates": "472,163"}, {"time": "4.06", "coordinates": "472,164"}, {"time": "4.08", "coordinates": "470,167"}, {"time": "4.09", "coordinates": "468,170"}, {"time": "4.11", "coordinates": "465,172"}, {"time": "4.13", "coordinates": "464,174"}, {"time": "4.14", "coordinates": "462,176"}, {"time": "4.16", "coordinates": "461,176"}, {"time": "4.18", "coordinates": "460,177"}, {"time": "4.25", "coordinates": "453,183"}, {"time": "4.26", "coordinates": "452,183"}, {"time": "4.28", "coordinates": "452,184"}, {"time": "4.29", "coordinates": "452,185"}, {"time": "4.31", "coordinates": "452,186"}, {"time": "4.33", "coordinates": "450,188"}, {"time": "4.34", "coordinates": "449,189"}, {"time": "4.37", "coordinates": "448,189"}, {"time": "4.38", "coordinates": "448,190"}, {"time": "4.39", "coordinates": "448,191"}, {"time": "4.44", "coordinates": "447,192"}, {"time": "4.46", "coordinates": "445,193"}, {"time": "4.49", "coordinates": "444,193"}, {"time": "4.49", "coordinates": "444,194"}, {"time": "4.55", "coordinates": "443,194"}, {"time": "4.63", "coordinates": "442,194"}, {"time": "4.68", "coordinates": "442,193"}, {"time": "4.7", "coordinates": "442,192"}, {"time": "4.83", "coordinates": "442,192"}, {"time": "5.33", "coordinates": "442,195"}, {"time": "5.34", "coordinates": "444,197"}, {"time": "5.36", "coordinates": "445,203"}, {"time": "5.38", "coordinates": "447,205"}, {"time": "5.39", "coordinates": "447,207"}, {"time": "5.41", "coordinates": "448,208"}, {"time": "5.43", "coordinates": "448,209"}, {"time": "5.45", "coordinates": "448,210"}, {"time": "5.51", "coordinates": "448,209"}, {"time": "5.53", "coordinates": "448,208"}, {"time": "5.54", "coordinates": "447,207"}, {"time": "5.56", "coordinates": "445,205"}, {"time": "5.58", "coordinates": "445,203"}, {"time": "5.59", "coordinates": "444,202"}, {"time": "5.61", "coordinates": "443,200"}, {"time": "5.63", "coordinates": "442,198"}, {"time": "5.64", "coordinates": "441,197"}, {"time": "5.66", "coordinates": "441,196"}, {"time": "5.68", "coordinates": "440,196"}, {"time": "5.69", "coordinates": "440,195"}, {"time": "5.71", "coordinates": "440,194"}, {"time": "5.73", "coordinates": "439,194"}, {"time": "5.74", "coordinates": "439,193"}, {"time": "5.76", "coordinates": "439,192"}, {"time": "5.81", "coordinates": "439,191"}, {"time": "5.83", "coordinates": "439,190"}, {"time": "5.85", "coordinates": "439,189"}, {"time": "5.89", "coordinates": "440,189"}, {"time": "6.32", "coordinates": "440,188"}, {"time": "6.33", "coordinates": "439,188"}, {"time": "6.34", "coordinates": "438,188"}, {"time": "6.36", "coordinates": "437,187"}, {"time": "6.38", "coordinates": "436,186"}, {"time": "6.39", "coordinates": "435,186"}, {"time": "6.41", "coordinates": "435,185"}, {"time": "6.43", "coordinates": "433,185"}, {"time": "6.65", "coordinates": "433,186"}, {"time": "6.66", "coordinates": "434,186"}, {"time": "6.71", "coordinates": "435,186"}, {"time": "6.74", "coordinates": "436,18 ...
# JSONDecodeError: Unterminated string starting at: line 1 column 32766 (char 32765) in row [{"time": "0.74", "coordinates": "612,450"}, {"time": "0.76", "coordinates": "592,404"}, {"time": "0.78", "coordinates": "568,336"}, {"time": "0.79", "coordinates": "544,257"}, {"time": "0.81", "coordinates": "508,140"}, {"time": "0.83", "coordinates": "486,76"}, {"time": "0.84", "coordinates": "458,22"}, {"time": "0.86", "coordinates": "447,9"}, {"time": "0.88", "coordinates": "442,4"}, {"time": "0.89", "coordinates": "440,2"}, {"time": "0.91", "coordinates": "438,0"}, {"time": "0.93", "coordinates": "437,0"}, {"time": "0.94", "coordinates": "436,0"}, {"time": "0.99", "coordinates": "435,0"}, {"time": "1.01", "coordinates": "434,0"}, {"time": "1.02", "coordinates": "433,0"}, {"time": "1.04", "coordinates": "432,0"}, {"time": "1.09", "coordinates": "431,1"}, {"time": "1.11", "coordinates": "430,3"}, {"time": "1.13", "coordinates": "430,4"}, {"time": "1.14", "coordinates": "429,8"}, {"time": "1.17", "coordinates": "427,40"}, {"time": "1.18", "coordinates": "427,51"}, {"time": "1.19", "coordinates": "427,70"}, {"time": "1.21", "coordinates": "430,92"}, {"time": "1.23", "coordinates": "430,98"}, {"time": "1.24", "coordinates": "431,102"}, {"time": "1.26", "coordinates": "432,104"}, {"time": "1.28", "coordinates": "432,105"}, {"time": "1.3", "coordinates": "432,106"}, {"time": "1.34", "coordinates": "432,107"}, {"time": "2.33", "coordinates": "434,109"}, {"time": "2.34", "coordinates": "440,115"}, {"time": "2.36", "coordinates": "446,123"}, {"time": "2.38", "coordinates": "456,135"}, {"time": "2.39", "coordinates": "459,141"}, {"time": "2.41", "coordinates": "461,145"}, {"time": "2.42", "coordinates": "462,148"}, {"time": "2.44", "coordinates": "463,150"}, {"time": "2.46", "coordinates": "463,152"}, {"time": "2.48", "coordinates": "463,153"}, {"time": "2.5", "coordinates": "463,154"}, {"time": "2.54", "coordinates": "463,156"}, {"time": "2.56", "coordinates": "462,156"}, {"time": "2.58", "coordinates": "461,156"}, {"time": "2.59", "coordinates": "461,158"}, {"time": "2.61", "coordinates": "460,159"}, {"time": "2.63", "coordinates": "460,160"}, {"time": "2.64", "coordinates": "460,162"}, {"time": "2.66", "coordinates": "458,165"}, {"time": "2.68", "coordinates": "456,169"}, {"time": "2.69", "coordinates": "455,172"}, {"time": "2.71", "coordinates": "452,178"}, {"time": "2.72", "coordinates": "452,182"}, {"time": "2.74", "coordinates": "451,184"}, {"time": "2.76", "coordinates": "448,187"}, {"time": "2.77", "coordinates": "448,189"}, {"time": "2.79", "coordinates": "448,190"}, {"time": "2.81", "coordinates": "447,192"}, {"time": "2.83", "coordinates": "446,192"}, {"time": "2.84", "coordinates": "445,193"}, {"time": "2.87", "coordinates": "444,193"}, {"time": "2.88", "coordinates": "444,194"}, {"time": "2.89", "coordinates": "444,195"}, {"time": "2.91", "coordinates": "443,195"}, {"time": "2.92", "coordinates": "443,196"}, {"time": "2.94", "coordinates": "442,196"}, {"time": "2.96", "coordinates": "441,196"}, {"time": "2.99", "coordinates": "440,196"}, {"time": "3.04", "coordinates": "439,196"}, {"time": "3.06", "coordinates": "438,196"}, {"time": "3.07", "coordinates": "436,196"}, {"time": "3.1", "coordinates": "435,196"}, {"time": "3.14", "coordinates": "433,196"}, {"time": "3.16", "coordinates": "433,195"}, {"time": "3.17", "coordinates": "432,194"}, {"time": "3.19", "coordinates": "432,193"}, {"time": "3.21", "coordinates": "432,192"}, {"time": "3.26", "coordinates": "432,190"}, {"time": "3.27", "coordinates": "432,189"}, {"time": "3.29", "coordinates": "432,188"}, {"time": "3.31", "coordinates": "432,187"}, {"time": "3.33", "coordinates": "432,186"}, {"time": "3.34", "coordinates": "432,185"}, {"time": "3.36", "coordinates": "432,184"}, {"time": "3.38", "coordinates": "433,184"}, {"time": "4.34", "coordinates": "436,189"}, {"time": "4.37", "coordinates": "451,225"}, {"time": "4.37", "coordinates": "458,248"}, {"time": "4.39", "coordinates": ...
# JSONDecodeError: Unterminated string starting at: line 1 column 32766 (char 32765) in row [{"time": "0.74", "coordinates": "612,450"}, {"time": "0.76", "coordinates": "592,404"}, {"time": "0.78", "coordinates": "568,336"}, {"time": "0.79", "coordinates": "544,257"}, {"time": "0.81", "coordinates": "508,140"}, {"time": "0.83", "coordinates": "486,76"}, {"time": "0.84", "coordinates": "458,22"}, {"time": "0.86", "coordinates": "447,9"}, {"time": "0.88", "coordinates": "442,4"}, {"time": "0.89", "coordinates": "440,2"}, {"time": "0.91", "coordinates": "438,0"}, {"time": "0.93", "coordinates": "437,0"}, {"time": "0.94", "coordinates": "436,0"}, {"time": "0.99", "coordinates": "435,0"}, {"time": "1.01", "coordinates": "434,0"}, {"time": "1.02", "coordinates": "433,0"}, {"time": "1.04", "coordinates": "432,0"}, {"time": "1.09", "coordinates": "431,1"}, {"time": "1.11", "coordinates": "430,3"}, {"time": "1.13", "coordinates": "430,4"}, {"time": "1.14", "coordinates": "429,8"}, {"time": "1.17", "coordinates": "427,40"}, {"time": "1.18", "coordinates": "427,51"}, {"time": "1.19", "coordinates": "427,70"}, {"time": "1.21", "coordinates": "430,92"}, {"time": "1.23", "coordinates": "430,98"}, {"time": "1.24", "coordinates": "431,102"}, {"time": "1.26", "coordinates": "432,104"}, {"time": "1.28", "coordinates": "432,105"}, {"time": "1.3", "coordinates": "432,106"}, {"time": "1.34", "coordinates": "432,107"}, {"time": "2.33", "coordinates": "434,109"}, {"time": "2.34", "coordinates": "440,115"}, {"time": "2.36", "coordinates": "446,123"}, {"time": "2.38", "coordinates": "456,135"}, {"time": "2.39", "coordinates": "459,141"}, {"time": "2.41", "coordinates": "461,145"}, {"time": "2.42", "coordinates": "462,148"}, {"time": "2.44", "coordinates": "463,150"}, {"time": "2.46", "coordinates": "463,152"}, {"time": "2.48", "coordinates": "463,153"}, {"time": "2.5", "coordinates": "463,154"}, {"time": "2.54", "coordinates": "463,156"}, {"time": "2.56", "coordinates": "462,156"}, {"time": "2.58", "coordinates": "461,156"}, {"time": "2.59", "coordinates": "461,158"}, {"time": "2.61", "coordinates": "460,159"}, {"time": "2.63", "coordinates": "460,160"}, {"time": "2.64", "coordinates": "460,162"}, {"time": "2.66", "coordinates": "458,165"}, {"time": "2.68", "coordinates": "456,169"}, {"time": "2.69", "coordinates": "455,172"}, {"time": "2.71", "coordinates": "452,178"}, {"time": "2.72", "coordinates": "452,182"}, {"time": "2.74", "coordinates": "451,184"}, {"time": "2.76", "coordinates": "448,187"}, {"time": "2.77", "coordinates": "448,189"}, {"time": "2.79", "coordinates": "448,190"}, {"time": "2.81", "coordinates": "447,192"}, {"time": "2.83", "coordinates": "446,192"}, {"time": "2.84", "coordinates": "445,193"}, {"time": "2.87", "coordinates": "444,193"}, {"time": "2.88", "coordinates": "444,194"}, {"time": "2.89", "coordinates": "444,195"}, {"time": "2.91", "coordinates": "443,195"}, {"time": "2.92", "coordinates": "443,196"}, {"time": "2.94", "coordinates": "442,196"}, {"time": "2.96", "coordinates": "441,196"}, {"time": "2.99", "coordinates": "440,196"}, {"time": "3.04", "coordinates": "439,196"}, {"time": "3.06", "coordinates": "438,196"}, {"time": "3.07", "coordinates": "436,196"}, {"time": "3.1", "coordinates": "435,196"}, {"time": "3.14", "coordinates": "433,196"}, {"time": "3.16", "coordinates": "433,195"}, {"time": "3.17", "coordinates": "432,194"}, {"time": "3.19", "coordinates": "432,193"}, {"time": "3.21", "coordinates": "432,192"}, {"time": "3.26", "coordinates": "432,190"}, {"time": "3.27", "coordinates": "432,189"}, {"time": "3.29", "coordinates": "432,188"}, {"time": "3.31", "coordinates": "432,187"}, {"time": "3.33", "coordinates": "432,186"}, {"time": "3.34", "coordinates": "432,185"}, {"time": "3.36", "coordinates": "432,184"}, {"time": "3.38", "coordinates": "433,184"}, {"time": "4.34", "coordinates": "436,189"}, {"time": "4.37", "coordinates": "451,225"}, {"time": "4.37", "coordinates": "458,248"}, {"time": "4.39", "coordinates": ...
# JSONDecodeError: Unterminated string starting at: line 1 column 32763 (char 32762) in row [{"time": "0.06", "coordinates": "98,1"}, {"time": "0.07", "coordinates": "135,60"}, {"time": "0.09", "coordinates": "169,119"}, {"time": "0.1", "coordinates": "188,148"}, {"time": "0.13", "coordinates": "283,306"}, {"time": "0.14", "coordinates": "297,330"}, {"time": "0.15", "coordinates": "312,352"}, {"time": "1.99", "coordinates": "348,336"}, {"time": "2.0", "coordinates": "393,313"}, {"time": "2.02", "coordinates": "505,261"}, {"time": "2.03", "coordinates": "562,236"}, {"time": "2.05", "coordinates": "598,220"}, {"time": "2.07", "coordinates": "628,203"}, {"time": "2.08", "coordinates": "637,199"}, {"time": "2.1", "coordinates": "642,196"}, {"time": "2.12", "coordinates": "644,195"}, {"time": "4.03", "coordinates": "613,180"}, {"time": "4.05", "coordinates": "591,172"}, {"time": "4.07", "coordinates": "551,156"}, {"time": "4.08", "coordinates": "543,152"}, {"time": "4.1", "coordinates": "526,146"}, {"time": "4.12", "coordinates": "508,138"}, {"time": "4.13", "coordinates": "503,135"}, {"time": "4.15", "coordinates": "498,132"}, {"time": "4.17", "coordinates": "492,129"}, {"time": "4.18", "coordinates": "489,127"}, {"time": "4.2", "coordinates": "487,125"}, {"time": "4.22", "coordinates": "483,124"}, {"time": "4.23", "coordinates": "480,122"}, {"time": "4.25", "coordinates": "477,120"}, {"time": "4.27", "coordinates": "476,120"}, {"time": "4.28", "coordinates": "476,119"}, {"time": "4.3", "coordinates": "474,119"}, {"time": "4.32", "coordinates": "474,118"}, {"time": "4.33", "coordinates": "473,117"}, {"time": "4.35", "coordinates": "473,116"}, {"time": "4.37", "coordinates": "473,112"}, {"time": "4.38", "coordinates": "473,108"}, {"time": "4.4", "coordinates": "473,100"}, {"time": "4.42", "coordinates": "473,89"}, {"time": "4.43", "coordinates": "473,71"}, {"time": "4.45", "coordinates": "473,63"}, {"time": "4.47", "coordinates": "473,56"}, {"time": "4.48", "coordinates": "473,49"}, {"time": "4.5", "coordinates": "473,46"}, {"time": "4.52", "coordinates": "473,44"}, {"time": "4.54", "coordinates": "473,43"}, {"time": "5.04", "coordinates": "460,41"}, {"time": "5.05", "coordinates": "404,27"}, {"time": "5.06", "coordinates": "340,12"}, {"time": "6.76", "coordinates": "286,3"}, {"time": "6.78", "coordinates": "312,13"}, {"time": "6.8", "coordinates": "331,23"}, {"time": "6.82", "coordinates": "352,32"}, {"time": "6.83", "coordinates": "358,36"}, {"time": "6.85", "coordinates": "362,38"}, {"time": "6.87", "coordinates": "364,40"}, {"time": "6.88", "coordinates": "364,41"}, {"time": "6.9", "coordinates": "364,43"}, {"time": "6.92", "coordinates": "365,44"}, {"time": "6.93", "coordinates": "366,46"}, {"time": "6.95", "coordinates": "366,50"}, {"time": "6.97", "coordinates": "366,52"}, {"time": "6.98", "coordinates": "366,57"}, {"time": "7.0", "coordinates": "366,65"}, {"time": "7.02", "coordinates": "367,72"}, {"time": "7.03", "coordinates": "368,78"}, {"time": "7.05", "coordinates": "370,85"}, {"time": "7.07", "coordinates": "372,90"}, {"time": "7.08", "coordinates": "376,94"}, {"time": "7.1", "coordinates": "382,100"}, {"time": "7.12", "coordinates": "387,106"}, {"time": "7.13", "coordinates": "393,113"}, {"time": "7.15", "coordinates": "397,116"}, {"time": "7.17", "coordinates": "400,119"}, {"time": "7.18", "coordinates": "404,122"}, {"time": "7.2", "coordinates": "406,124"}, {"time": "7.21", "coordinates": "408,126"}, {"time": "7.23", "coordinates": "412,128"}, {"time": "7.25", "coordinates": "414,131"}, {"time": "7.27", "coordinates": "417,133"}, {"time": "7.28", "coordinates": "419,136"}, {"time": "7.3", "coordinates": "420,138"}, {"time": "7.32", "coordinates": "424,141"}, {"time": "7.33", "coordinates": "425,144"}, {"time": "7.35", "coordinates": "428,148"}, {"time": "7.37", "coordinates": "429,149"}, {"time": "7.38", "coordinates": "430,150"}, {"time": "7.4", "coordinates": "431,152"}, {"time": "7.42", "coordinates": "432,152"},  ...
# JSONDecodeError: Unterminated string starting at: line 1 column 32756 (char 32755) in row [{"time": "1.65", "coordinates": "730,453"}, {"time": "1.65", "coordinates": "705,436"}, {"time": "1.66", "coordinates": "683,418"}, {"time": "1.67", "coordinates": "659,402"}, {"time": "1.68", "coordinates": "618,368"}, {"time": "1.69", "coordinates": "604,351"}, {"time": "1.7", "coordinates": "592,336"}, {"time": "1.7", "coordinates": "583,321"}, {"time": "1.71", "coordinates": "560,283"}, {"time": "1.72", "coordinates": "553,265"}, {"time": "1.73", "coordinates": "547,251"}, {"time": "1.74", "coordinates": "542,240"}, {"time": "1.74", "coordinates": "540,231"}, {"time": "1.75", "coordinates": "537,222"}, {"time": "1.76", "coordinates": "536,221"}, {"time": "1.77", "coordinates": "536,218"}, {"time": "1.78", "coordinates": "536,217"}, {"time": "1.79", "coordinates": "536,216"}, {"time": "1.79", "coordinates": "536,215"}, {"time": "1.8", "coordinates": "536,214"}, {"time": "1.84", "coordinates": "536,213"}, {"time": "2.32", "coordinates": "568,208"}, {"time": "2.33", "coordinates": "591,205"}, {"time": "2.33", "coordinates": "608,202"}, {"time": "2.34", "coordinates": "637,198"}, {"time": "2.35", "coordinates": "647,197"}, {"time": "2.36", "coordinates": "655,195"}, {"time": "2.37", "coordinates": "659,194"}, {"time": "2.38", "coordinates": "661,193"}, {"time": "2.38", "coordinates": "664,193"}, {"time": "2.4", "coordinates": "665,193"}, {"time": "2.41", "coordinates": "666,193"}, {"time": "2.43", "coordinates": "667,193"}, {"time": "2.45", "coordinates": "668,193"}, {"time": "3.02", "coordinates": "654,186"}, {"time": "3.03", "coordinates": "628,175"}, {"time": "3.04", "coordinates": "588,159"}, {"time": "3.05", "coordinates": "564,151"}, {"time": "3.05", "coordinates": "542,145"}, {"time": "3.06", "coordinates": "529,143"}, {"time": "3.07", "coordinates": "517,141"}, {"time": "3.08", "coordinates": "504,139"}, {"time": "3.09", "coordinates": "480,136"}, {"time": "3.09", "coordinates": "471,134"}, {"time": "3.1", "coordinates": "466,134"}, {"time": "3.11", "coordinates": "461,133"}, {"time": "3.12", "coordinates": "456,133"}, {"time": "3.13", "coordinates": "454,133"}, {"time": "3.13", "coordinates": "452,132"}, {"time": "3.14", "coordinates": "451,132"}, {"time": "3.15", "coordinates": "448,132"}, {"time": "3.16", "coordinates": "445,132"}, {"time": "3.17", "coordinates": "443,132"}, {"time": "3.18", "coordinates": "442,132"}, {"time": "3.19", "coordinates": "440,132"}, {"time": "3.19", "coordinates": "437,132"}, {"time": "3.2", "coordinates": "434,132"}, {"time": "3.21", "coordinates": "432,132"}, {"time": "3.22", "coordinates": "430,132"}, {"time": "3.23", "coordinates": "428,132"}, {"time": "3.24", "coordinates": "425,132"}, {"time": "3.25", "coordinates": "424,132"}, {"time": "3.25", "coordinates": "423,132"}, {"time": "3.26", "coordinates": "420,131"}, {"time": "3.27", "coordinates": "417,131"}, {"time": "3.28", "coordinates": "416,131"}, {"time": "3.29", "coordinates": "415,131"}, {"time": "3.3", "coordinates": "413,131"}, {"time": "3.3", "coordinates": "412,131"}, {"time": "3.31", "coordinates": "411,131"}, {"time": "3.32", "coordinates": "410,131"}, {"time": "3.33", "coordinates": "409,131"}, {"time": "3.34", "coordinates": "408,131"}, {"time": "3.37", "coordinates": "407,131"}, {"time": "3.38", "coordinates": "407,132"}, {"time": "3.39", "coordinates": "406,133"}, {"time": "3.41", "coordinates": "405,135"}, {"time": "3.42", "coordinates": "404,137"}, {"time": "3.43", "coordinates": "404,138"}, {"time": "3.44", "coordinates": "404,139"}, {"time": "3.44", "coordinates": "404,140"}, {"time": "3.45", "coordinates": "404,141"}, {"time": "3.49", "coordinates": "404,142"}, {"time": "3.51", "coordinates": "404,143"}, {"time": "3.65", "coordinates": "405,143"}, {"time": "3.66", "coordinates": "405,142"}, {"time": "3.66", "coordinates": "406,142"}, {"time": "3.68", "coordinates": "406,141"}, {"time": "3.7", "coordinates": "407,141"}, {" ...
# JSONDecodeError: Unterminated string starting at: line 1 column 32766 (char 32765) in row [{"time": "0.82", "coordinates": "642,461"}, {"time": "0.83", "coordinates": "628,449"}, {"time": "0.85", "coordinates": "616,430"}, {"time": "0.86", "coordinates": "604,407"}, {"time": "0.88", "coordinates": "591,377"}, {"time": "0.9", "coordinates": "584,362"}, {"time": "0.91", "coordinates": "580,350"}, {"time": "0.93", "coordinates": "576,337"}, {"time": "0.95", "coordinates": "575,333"}, {"time": "0.96", "coordinates": "574,327"}, {"time": "0.98", "coordinates": "573,315"}, {"time": "1.0", "coordinates": "573,308"}, {"time": "1.01", "coordinates": "573,302"}, {"time": "1.03", "coordinates": "573,297"}, {"time": "1.05", "coordinates": "573,294"}, {"time": "1.06", "coordinates": "573,290"}, {"time": "1.08", "coordinates": "573,285"}, {"time": "1.1", "coordinates": "574,280"}, {"time": "1.11", "coordinates": "574,277"}, {"time": "1.13", "coordinates": "574,270"}, {"time": "1.15", "coordinates": "574,267"}, {"time": "1.16", "coordinates": "574,265"}, {"time": "1.18", "coordinates": "574,261"}, {"time": "1.2", "coordinates": "574,258"}, {"time": "1.21", "coordinates": "575,252"}, {"time": "1.23", "coordinates": "575,249"}, {"time": "1.25", "coordinates": "576,244"}, {"time": "1.26", "coordinates": "576,241"}, {"time": "1.59", "coordinates": "573,238"}, {"time": "1.6", "coordinates": "567,236"}, {"time": "1.61", "coordinates": "564,233"}, {"time": "1.63", "coordinates": "554,224"}, {"time": "1.65", "coordinates": "548,217"}, {"time": "1.66", "coordinates": "544,210"}, {"time": "1.68", "coordinates": "538,204"}, {"time": "1.7", "coordinates": "534,200"}, {"time": "1.71", "coordinates": "532,196"}, {"time": "1.73", "coordinates": "526,190"}, {"time": "1.75", "coordinates": "524,186"}, {"time": "1.76", "coordinates": "523,183"}, {"time": "1.78", "coordinates": "520,179"}, {"time": "1.8", "coordinates": "520,178"}, {"time": "1.85", "coordinates": "520,177"}, {"time": "2.08", "coordinates": "520,176"}, {"time": "2.19", "coordinates": "520,175"}, {"time": "2.2", "coordinates": "520,174"}, {"time": "2.22", "coordinates": "520,173"}, {"time": "2.32", "coordinates": "520,172"}, {"time": "2.33", "coordinates": "519,172"}, {"time": "3.94", "coordinates": "520,174"}, {"time": "3.96", "coordinates": "523,182"}, {"time": "3.98", "coordinates": "527,193"}, {"time": "3.99", "coordinates": "532,213"}, {"time": "4.01", "coordinates": "536,227"}, {"time": "4.03", "coordinates": "540,239"}, {"time": "4.04", "coordinates": "549,263"}, {"time": "4.06", "coordinates": "554,275"}, {"time": "4.08", "coordinates": "559,289"}, {"time": "4.09", "coordinates": "564,306"}, {"time": "4.11", "coordinates": "565,313"}, {"time": "4.13", "coordinates": "567,315"}, {"time": "4.14", "coordinates": "567,318"}, {"time": "4.16", "coordinates": "567,319"}, {"time": "4.21", "coordinates": "567,320"}, {"time": "4.39", "coordinates": "566,320"}, {"time": "4.39", "coordinates": "565,320"}, {"time": "4.41", "coordinates": "560,317"}, {"time": "4.43", "coordinates": "552,307"}, {"time": "4.44", "coordinates": "540,292"}, {"time": "4.46", "coordinates": "531,277"}, {"time": "4.48", "coordinates": "523,260"}, {"time": "4.49", "coordinates": "511,239"}, {"time": "4.51", "coordinates": "502,226"}, {"time": "4.53", "coordinates": "496,214"}, {"time": "4.54", "coordinates": "488,203"}, {"time": "4.56", "coordinates": "485,200"}, {"time": "4.58", "coordinates": "483,196"}, {"time": "4.59", "coordinates": "480,190"}, {"time": "4.61", "coordinates": "479,189"}, {"time": "4.63", "coordinates": "478,186"}, {"time": "4.64", "coordinates": "478,185"}, {"time": "4.66", "coordinates": "477,185"}, {"time": "4.68", "coordinates": "477,184"}, {"time": "4.69", "coordinates": "476,184"}, {"time": "4.71", "coordinates": "475,182"}, {"time": "4.73", "coordinates": "474,181"}, {"time": "4.74", "coordinates": "472,177"}, {"time": "4.76", "coordinates": "470,173"}, {"time": "4.78", "coordinates": "468,171"}, { ...
# JSONDecodeError: Unterminated string starting at: line 1 column 32766 (char 32765) in row [{"time": "0.82", "coordinates": "642,461"}, {"time": "0.83", "coordinates": "628,449"}, {"time": "0.85", "coordinates": "616,430"}, {"time": "0.86", "coordinates": "604,407"}, {"time": "0.88", "coordinates": "591,377"}, {"time": "0.9", "coordinates": "584,362"}, {"time": "0.91", "coordinates": "580,350"}, {"time": "0.93", "coordinates": "576,337"}, {"time": "0.95", "coordinates": "575,333"}, {"time": "0.96", "coordinates": "574,327"}, {"time": "0.98", "coordinates": "573,315"}, {"time": "1.0", "coordinates": "573,308"}, {"time": "1.01", "coordinates": "573,302"}, {"time": "1.03", "coordinates": "573,297"}, {"time": "1.05", "coordinates": "573,294"}, {"time": "1.06", "coordinates": "573,290"}, {"time": "1.08", "coordinates": "573,285"}, {"time": "1.1", "coordinates": "574,280"}, {"time": "1.11", "coordinates": "574,277"}, {"time": "1.13", "coordinates": "574,270"}, {"time": "1.15", "coordinates": "574,267"}, {"time": "1.16", "coordinates": "574,265"}, {"time": "1.18", "coordinates": "574,261"}, {"time": "1.2", "coordinates": "574,258"}, {"time": "1.21", "coordinates": "575,252"}, {"time": "1.23", "coordinates": "575,249"}, {"time": "1.25", "coordinates": "576,244"}, {"time": "1.26", "coordinates": "576,241"}, {"time": "1.59", "coordinates": "573,238"}, {"time": "1.6", "coordinates": "567,236"}, {"time": "1.61", "coordinates": "564,233"}, {"time": "1.63", "coordinates": "554,224"}, {"time": "1.65", "coordinates": "548,217"}, {"time": "1.66", "coordinates": "544,210"}, {"time": "1.68", "coordinates": "538,204"}, {"time": "1.7", "coordinates": "534,200"}, {"time": "1.71", "coordinates": "532,196"}, {"time": "1.73", "coordinates": "526,190"}, {"time": "1.75", "coordinates": "524,186"}, {"time": "1.76", "coordinates": "523,183"}, {"time": "1.78", "coordinates": "520,179"}, {"time": "1.8", "coordinates": "520,178"}, {"time": "1.85", "coordinates": "520,177"}, {"time": "2.08", "coordinates": "520,176"}, {"time": "2.19", "coordinates": "520,175"}, {"time": "2.2", "coordinates": "520,174"}, {"time": "2.22", "coordinates": "520,173"}, {"time": "2.32", "coordinates": "520,172"}, {"time": "2.33", "coordinates": "519,172"}, {"time": "3.94", "coordinates": "520,174"}, {"time": "3.96", "coordinates": "523,182"}, {"time": "3.98", "coordinates": "527,193"}, {"time": "3.99", "coordinates": "532,213"}, {"time": "4.01", "coordinates": "536,227"}, {"time": "4.03", "coordinates": "540,239"}, {"time": "4.04", "coordinates": "549,263"}, {"time": "4.06", "coordinates": "554,275"}, {"time": "4.08", "coordinates": "559,289"}, {"time": "4.09", "coordinates": "564,306"}, {"time": "4.11", "coordinates": "565,313"}, {"time": "4.13", "coordinates": "567,315"}, {"time": "4.14", "coordinates": "567,318"}, {"time": "4.16", "coordinates": "567,319"}, {"time": "4.21", "coordinates": "567,320"}, {"time": "4.39", "coordinates": "566,320"}, {"time": "4.39", "coordinates": "565,320"}, {"time": "4.41", "coordinates": "560,317"}, {"time": "4.43", "coordinates": "552,307"}, {"time": "4.44", "coordinates": "540,292"}, {"time": "4.46", "coordinates": "531,277"}, {"time": "4.48", "coordinates": "523,260"}, {"time": "4.49", "coordinates": "511,239"}, {"time": "4.51", "coordinates": "502,226"}, {"time": "4.53", "coordinates": "496,214"}, {"time": "4.54", "coordinates": "488,203"}, {"time": "4.56", "coordinates": "485,200"}, {"time": "4.58", "coordinates": "483,196"}, {"time": "4.59", "coordinates": "480,190"}, {"time": "4.61", "coordinates": "479,189"}, {"time": "4.63", "coordinates": "478,186"}, {"time": "4.64", "coordinates": "478,185"}, {"time": "4.66", "coordinates": "477,185"}, {"time": "4.68", "coordinates": "477,184"}, {"time": "4.69", "coordinates": "476,184"}, {"time": "4.71", "coordinates": "475,182"}, {"time": "4.73", "coordinates": "474,181"}, {"time": "4.74", "coordinates": "472,177"}, {"time": "4.76", "coordinates": "470,173"}, {"time": "4.78", "coordinates": "468,171"}, { ...
# JSONDecodeError: Unterminated string starting at: line 1 column 32766 (char 32765) in row [{"time": "0.78", "coordinates": "444,453"}, {"time": "0.79", "coordinates": "424,438"}, {"time": "0.8", "coordinates": "408,428"}, {"time": "0.81", "coordinates": "369,383"}, {"time": "0.83", "coordinates": "348,352"}, {"time": "0.85", "coordinates": "332,328"}, {"time": "0.87", "coordinates": "312,291"}, {"time": "0.88", "coordinates": "303,274"}, {"time": "0.9", "coordinates": "296,256"}, {"time": "0.92", "coordinates": "293,251"}, {"time": "0.93", "coordinates": "292,248"}, {"time": "0.95", "coordinates": "290,245"}, {"time": "0.98", "coordinates": "290,246"}, {"time": "1.82", "coordinates": "290,255"}, {"time": "1.83", "coordinates": "293,288"}, {"time": "1.85", "coordinates": "297,322"}, {"time": "1.87", "coordinates": "301,374"}, {"time": "1.88", "coordinates": "304,400"}, {"time": "1.9", "coordinates": "305,433"}, {"time": "1.92", "coordinates": "306,445"}, {"time": "1.93", "coordinates": "306,451"}, {"time": "1.95", "coordinates": "307,458"}, {"time": "1.97", "coordinates": "307,460"}, {"time": "2.0", "coordinates": "307,461"}, {"time": "2.03", "coordinates": "307,460"}, {"time": "3.26", "coordinates": "300,431"}, {"time": "3.28", "coordinates": "275,357"}, {"time": "3.3", "coordinates": "256,297"}, {"time": "3.31", "coordinates": "236,245"}, {"time": "3.33", "coordinates": "228,223"}, {"time": "3.35", "coordinates": "219,205"}, {"time": "3.37", "coordinates": "215,199"}, {"time": "3.38", "coordinates": "212,193"}, {"time": "3.4", "coordinates": "210,189"}, {"time": "3.41", "coordinates": "210,188"}, {"time": "3.43", "coordinates": "209,188"}, {"time": "3.5", "coordinates": "209,189"}, {"time": "3.57", "coordinates": "210,189"}, {"time": "3.58", "coordinates": "211,189"}, {"time": "3.6", "coordinates": "212,189"}, {"time": "3.62", "coordinates": "213,189"}, {"time": "3.63", "coordinates": "216,188"}, {"time": "3.65", "coordinates": "217,188"}, {"time": "3.66", "coordinates": "220,187"}, {"time": "3.68", "coordinates": "223,184"}, {"time": "3.7", "coordinates": "227,184"}, {"time": "3.71", "coordinates": "231,180"}, {"time": "3.73", "coordinates": "234,180"}, {"time": "3.75", "coordinates": "237,179"}, {"time": "3.77", "coordinates": "240,178"}, {"time": "3.78", "coordinates": "241,178"}, {"time": "3.8", "coordinates": "242,178"}, {"time": "3.81", "coordinates": "243,178"}, {"time": "3.84", "coordinates": "243,179"}, {"time": "3.86", "coordinates": "243,180"}, {"time": "4.02", "coordinates": "243,179"}, {"time": "4.06", "coordinates": "243,177"}, {"time": "4.08", "coordinates": "244,176"}, {"time": "4.1", "coordinates": "244,175"}, {"time": "4.11", "coordinates": "244,174"}, {"time": "4.13", "coordinates": "244,172"}, {"time": "4.15", "coordinates": "245,171"}, {"time": "4.17", "coordinates": "245,170"}, {"time": "4.18", "coordinates": "246,168"}, {"time": "4.21", "coordinates": "246,167"}, {"time": "4.22", "coordinates": "246,166"}, {"time": "4.24", "coordinates": "246,165"}, {"time": "4.39", "coordinates": "245,165"}, {"time": "4.45", "coordinates": "245,164"}, {"time": "4.57", "coordinates": "244,164"}, {"time": "6.11", "coordinates": "243,163"}, {"time": "6.12", "coordinates": "241,162"}, {"time": "6.13", "coordinates": "240,162"}, {"time": "6.15", "coordinates": "239,160"}, {"time": "6.16", "coordinates": "233,157"}, {"time": "6.18", "coordinates": "228,156"}, {"time": "6.2", "coordinates": "222,155"}, {"time": "6.21", "coordinates": "212,155"}, {"time": "6.23", "coordinates": "206,157"}, {"time": "6.25", "coordinates": "201,160"}, {"time": "6.26", "coordinates": "194,167"}, {"time": "6.28", "coordinates": "189,176"}, {"time": "6.3", "coordinates": "183,192"}, {"time": "6.31", "coordinates": "176,226"}, {"time": "6.33", "coordinates": "174,250"}, {"time": "6.35", "coordinates": "176,278"}, {"time": "6.36", "coordinates": "180,295"}, {"time": "6.38", "coordinates": "189,311"}, {"time": "6.4", "coordinates": "206,330"}, {"time" ...
# JSONDecodeError: Unterminated string starting at: line 1 column 32763 (char 32762) in row [{"time": "0.06", "coordinates": "125,14"}, {"time": "0.08", "coordinates": "167,72"}, {"time": "0.13", "coordinates": "224,140"}, {"time": "0.14", "coordinates": "228,142"}, {"time": "0.16", "coordinates": "237,149"}, {"time": "0.17", "coordinates": "242,152"}, {"time": "0.19", "coordinates": "246,156"}, {"time": "0.21", "coordinates": "250,159"}, {"time": "0.23", "coordinates": "252,160"}, {"time": "0.24", "coordinates": "253,162"}, {"time": "0.26", "coordinates": "255,163"}, {"time": "0.28", "coordinates": "255,164"}, {"time": "0.34", "coordinates": "255,163"}, {"time": "0.35", "coordinates": "254,162"}, {"time": "0.67", "coordinates": "254,166"}, {"time": "0.68", "coordinates": "254,172"}, {"time": "0.69", "coordinates": "254,179"}, {"time": "0.71", "coordinates": "252,197"}, {"time": "0.73", "coordinates": "252,205"}, {"time": "0.74", "coordinates": "251,215"}, {"time": "0.76", "coordinates": "250,220"}, {"time": "0.78", "coordinates": "249,221"}, {"time": "0.79", "coordinates": "249,223"}, {"time": "0.81", "coordinates": "249,224"}, {"time": "0.88", "coordinates": "249,223"}, {"time": "0.93", "coordinates": "249,221"}, {"time": "0.94", "coordinates": "249,220"}, {"time": "0.96", "coordinates": "249,219"}, {"time": "0.97", "coordinates": "249,217"}, {"time": "0.99", "coordinates": "249,216"}, {"time": "1.01", "coordinates": "249,214"}, {"time": "1.03", "coordinates": "249,212"}, {"time": "1.04", "coordinates": "249,211"}, {"time": "1.06", "coordinates": "250,209"}, {"time": "1.07", "coordinates": "252,208"}, {"time": "1.09", "coordinates": "255,204"}, {"time": "1.11", "coordinates": "263,197"}, {"time": "1.13", "coordinates": "269,192"}, {"time": "1.14", "coordinates": "274,189"}, {"time": "1.16", "coordinates": "278,188"}, {"time": "1.18", "coordinates": "279,188"}, {"time": "1.19", "coordinates": "280,188"}, {"time": "1.21", "coordinates": "281,188"}, {"time": "1.23", "coordinates": "282,190"}, {"time": "1.24", "coordinates": "282,191"}, {"time": "1.45", "coordinates": "281,191"}, {"time": "1.49", "coordinates": "280,191"}, {"time": "2.08", "coordinates": "279,191"}, {"time": "2.09", "coordinates": "278,191"}, {"time": "2.11", "coordinates": "274,191"}, {"time": "2.13", "coordinates": "272,191"}, {"time": "2.14", "coordinates": "270,191"}, {"time": "2.16", "coordinates": "268,190"}, {"time": "2.17", "coordinates": "267,189"}, {"time": "2.19", "coordinates": "266,189"}, {"time": "2.21", "coordinates": "265,188"}, {"time": "2.23", "coordinates": "264,187"}, {"time": "2.25", "coordinates": "264,186"}, {"time": "2.26", "coordinates": "264,185"}, {"time": "2.28", "coordinates": "263,184"}, {"time": "2.3", "coordinates": "262,184"}, {"time": "2.31", "coordinates": "261,183"}, {"time": "2.33", "coordinates": "261,181"}, {"time": "2.34", "coordinates": "260,180"}, {"time": "2.37", "coordinates": "260,179"}, {"time": "2.38", "coordinates": "259,178"}, {"time": "2.39", "coordinates": "259,177"}, {"time": "2.44", "coordinates": "258,177"}, {"time": "2.51", "coordinates": "257,177"}, {"time": "2.56", "coordinates": "257,176"}, {"time": "2.58", "coordinates": "256,176"}, {"time": "2.6", "coordinates": "256,175"}, {"time": "2.62", "coordinates": "255,174"}, {"time": "2.63", "coordinates": "255,173"}, {"time": "2.64", "coordinates": "254,173"}, {"time": "2.66", "coordinates": "253,173"}, {"time": "2.67", "coordinates": "253,172"}, {"time": "2.73", "coordinates": "252,172"}, {"time": "2.77", "coordinates": "252,171"}, {"time": "2.79", "coordinates": "252,170"}, {"time": "2.81", "coordinates": "250,169"}, {"time": "2.83", "coordinates": "248,168"}, {"time": "2.87", "coordinates": "246,167"}, {"time": "2.89", "coordinates": "246,166"}, {"time": "2.91", "coordinates": "245,166"}, {"time": "2.99", "coordinates": "245,165"}, {"time": "3.15", "coordinates": "245,164"}, {"time": "4.92", "coordinates": "252,183"}, {"time": "4.93", "coordinates": "266,214" ...
# JSONDecodeError: Unterminated string starting at: line 1 column 32764 (char 32763) in row [{"time": "0.14", "coordinates": "658,186"}, {"time": "0.15", "coordinates": "629,224"}, {"time": "0.17", "coordinates": "612,250"}, {"time": "0.18", "coordinates": "602,270"}, {"time": "0.2", "coordinates": "600,274"}, {"time": "0.22", "coordinates": "600,276"}, {"time": "0.23", "coordinates": "599,276"}, {"time": "0.28", "coordinates": "598,276"}, {"time": "0.64", "coordinates": "602,275"}, {"time": "0.65", "coordinates": "608,273"}, {"time": "0.67", "coordinates": "640,260"}, {"time": "0.68", "coordinates": "677,242"}, {"time": "0.7", "coordinates": "712,216"}, {"time": "0.72", "coordinates": "758,178"}, {"time": "0.73", "coordinates": "776,160"}, {"time": "0.75", "coordinates": "797,132"}, {"time": "0.77", "coordinates": "806,124"}, {"time": "0.78", "coordinates": "810,120"}, {"time": "0.8", "coordinates": "812,118"}, {"time": "0.81", "coordinates": "812,117"}, {"time": "0.83", "coordinates": "812,116"}, {"time": "0.85", "coordinates": "812,117"}, {"time": "0.86", "coordinates": "812,118"}, {"time": "0.88", "coordinates": "808,123"}, {"time": "0.9", "coordinates": "785,152"}, {"time": "0.92", "coordinates": "743,196"}, {"time": "0.93", "coordinates": "706,234"}, {"time": "0.95", "coordinates": "692,251"}, {"time": "0.96", "coordinates": "684,260"}, {"time": "0.98", "coordinates": "676,268"}, {"time": "1.0", "coordinates": "674,272"}, {"time": "1.01", "coordinates": "672,272"}, {"time": "1.03", "coordinates": "672,273"}, {"time": "12.09", "coordinates": "635,275"}, {"time": "12.1", "coordinates": "588,279"}, {"time": "12.11", "coordinates": "541,283"}, {"time": "12.13", "coordinates": "418,285"}, {"time": "12.14", "coordinates": "356,279"}, {"time": "12.16", "coordinates": "286,261"}, {"time": "12.18", "coordinates": "257,249"}, {"time": "12.19", "coordinates": "233,233"}, {"time": "12.21", "coordinates": "225,224"}, {"time": "12.23", "coordinates": "220,217"}, {"time": "12.24", "coordinates": "218,211"}, {"time": "12.26", "coordinates": "218,208"}, {"time": "12.28", "coordinates": "218,203"}, {"time": "12.29", "coordinates": "219,200"}, {"time": "12.31", "coordinates": "222,196"}, {"time": "12.33", "coordinates": "236,188"}, {"time": "12.35", "coordinates": "265,177"}, {"time": "12.36", "coordinates": "359,156"}, {"time": "12.38", "coordinates": "402,152"}, {"time": "12.39", "coordinates": "433,149"}, {"time": "12.41", "coordinates": "465,150"}, {"time": "12.43", "coordinates": "483,155"}, {"time": "12.45", "coordinates": "495,158"}, {"time": "12.46", "coordinates": "506,165"}, {"time": "12.48", "coordinates": "511,168"}, {"time": "12.49", "coordinates": "513,171"}, {"time": "12.51", "coordinates": "514,172"}, {"time": "12.53", "coordinates": "513,172"}, {"time": "12.54", "coordinates": "512,173"}, {"time": "12.56", "coordinates": "506,176"}, {"time": "12.95", "coordinates": "504,177"}, {"time": "12.96", "coordinates": "501,178"}, {"time": "12.98", "coordinates": "491,181"}, {"time": "12.99", "coordinates": "478,184"}, {"time": "13.01", "coordinates": "469,184"}, {"time": "13.03", "coordinates": "461,185"}, {"time": "13.04", "coordinates": "457,185"}, {"time": "13.06", "coordinates": "456,185"}, {"time": "13.09", "coordinates": "453,185"}, {"time": "13.14", "coordinates": "453,184"}, {"time": "13.62", "coordinates": "452,183"}, {"time": "13.63", "coordinates": "452,182"}, {"time": "13.64", "coordinates": "449,180"}, {"time": "13.66", "coordinates": "448,177"}, {"time": "13.68", "coordinates": "447,176"}, {"time": "13.71", "coordinates": "446,176"}, {"time": "13.72", "coordinates": "445,176"}, {"time": "13.77", "coordinates": "445,175"}, {"time": "13.81", "coordinates": "444,175"}, {"time": "13.86", "coordinates": "443,175"}, {"time": "13.88", "coordinates": "442,175"}, {"time": "13.9", "coordinates": "441,175"}, {"time": "13.96", "coordinates": "440,175"}, {"time": "13.99", "coordinates": "440,176"}, {"time": "14.01", "coordinates": " ...
# JSONDecodeError: Expecting value: line 1 column 32768 (char 32767) in row [{"time": "0.31", "coordinates": "599,471"}, {"time": "0.33", "coordinates": "597,469"}, {"time": "0.34", "coordinates": "588,460"}, {"time": "0.36", "coordinates": "572,445"}, {"time": "0.38", "coordinates": "548,421"}, {"time": "0.39", "coordinates": "508,361"}, {"time": "0.41", "coordinates": "493,335"}, {"time": "0.42", "coordinates": "480,310"}, {"time": "0.44", "coordinates": "476,302"}, {"time": "0.46", "coordinates": "475,299"}, {"time": "0.47", "coordinates": "473,298"}, {"time": "0.49", "coordinates": "472,298"}, {"time": "0.93", "coordinates": "472,282"}, {"time": "0.94", "coordinates": "472,252"}, {"time": "0.96", "coordinates": "470,197"}, {"time": "0.97", "coordinates": "468,176"}, {"time": "0.99", "coordinates": "465,165"}, {"time": "1.01", "coordinates": "464,160"}, {"time": "1.03", "coordinates": "463,159"}, {"time": "1.11", "coordinates": "462,159"}, {"time": "1.13", "coordinates": "461,160"}, {"time": "1.15", "coordinates": "460,160"}, {"time": "1.21", "coordinates": "458,160"}, {"time": "1.23", "coordinates": "457,159"}, {"time": "1.24", "coordinates": "455,158"}, {"time": "1.26", "coordinates": "452,158"}, {"time": "1.27", "coordinates": "450,158"}, {"time": "1.29", "coordinates": "448,160"}, {"time": "1.31", "coordinates": "446,161"}, {"time": "1.32", "coordinates": "445,161"}, {"time": "1.34", "coordinates": "444,163"}, {"time": "1.36", "coordinates": "443,164"}, {"time": "1.38", "coordinates": "442,165"}, {"time": "1.39", "coordinates": "441,165"}, {"time": "1.41", "coordinates": "441,166"}, {"time": "1.43", "coordinates": "440,166"}, {"time": "1.47", "coordinates": "440,167"}, {"time": "1.49", "coordinates": "440,168"}, {"time": "1.6", "coordinates": "440,167"}, {"time": "1.61", "coordinates": "440,166"}, {"time": "1.76", "coordinates": "439,166"}, {"time": "1.85", "coordinates": "439,165"}, {"time": "2.13", "coordinates": "436,180"}, {"time": "2.14", "coordinates": "432,198"}, {"time": "2.16", "coordinates": "422,240"}, {"time": "2.17", "coordinates": "418,253"}, {"time": "2.19", "coordinates": "415,264"}, {"time": "2.21", "coordinates": "414,266"}, {"time": "2.22", "coordinates": "413,268"}, {"time": "2.24", "coordinates": "412,271"}, {"time": "2.91", "coordinates": "420,264"}, {"time": "2.91", "coordinates": "436,254"}, {"time": "2.92", "coordinates": "447,247"}, {"time": "2.94", "coordinates": "472,228"}, {"time": "2.96", "coordinates": "483,220"}, {"time": "2.97", "coordinates": "489,216"}, {"time": "2.99", "coordinates": "496,212"}, {"time": "3.01", "coordinates": "497,210"}, {"time": "3.02", "coordinates": "498,210"}, {"time": "3.04", "coordinates": "500,209"}, {"time": "3.06", "coordinates": "500,208"}, {"time": "3.07", "coordinates": "501,208"}, {"time": "3.1", "coordinates": "502,207"}, {"time": "3.11", "coordinates": "502,206"}, {"time": "3.12", "coordinates": "504,206"}, {"time": "3.17", "coordinates": "505,206"}, {"time": "17.75", "coordinates": "501,212"}, {"time": "17.77", "coordinates": "479,238"}, {"time": "17.79", "coordinates": "460,260"}, {"time": "17.8", "coordinates": "441,281"}, {"time": "17.82", "coordinates": "436,287"}, {"time": "17.84", "coordinates": "432,292"}, {"time": "17.86", "coordinates": "432,293"}, {"time": "17.9", "coordinates": "431,296"}, {"time": "17.92", "coordinates": "430,296"}, {"time": "22.66", "coordinates": "432,296"}, {"time": "22.67", "coordinates": "437,296"}, {"time": "22.68", "coordinates": "448,292"}, {"time": "22.7", "coordinates": "458,289"}, {"time": "22.72", "coordinates": "472,284"}, {"time": "22.73", "coordinates": "480,280"}, {"time": "22.75", "coordinates": "488,278"}, {"time": "22.77", "coordinates": "498,272"}, {"time": "22.79", "coordinates": "504,269"}, {"time": "22.8", "coordinates": "507,268"}, {"time": "22.82", "coordinates": "511,266"}, {"time": "22.84", "coordinates": "513,265"}, {"time": "22.85", "coordinates": "514,265"}, {"time": "22.87", "coordinates": "515 ...
# JSONDecodeError: Unterminated string starting at: line 1 column 32760 (char 32759) in row [{"time": "2.07", "coordinates": "412,226"}, {"time": "2.08", "coordinates": "421,220"}, {"time": "2.09", "coordinates": "437,210"}, {"time": "2.11", "coordinates": "456,196"}, {"time": "2.13", "coordinates": "468,188"}, {"time": "2.14", "coordinates": "476,181"}, {"time": "2.16", "coordinates": "477,179"}, {"time": "2.18", "coordinates": "479,178"}, {"time": "2.19", "coordinates": "480,177"}, {"time": "2.29", "coordinates": "480,178"}, {"time": "2.33", "coordinates": "479,178"}, {"time": "2.34", "coordinates": "478,179"}, {"time": "2.36", "coordinates": "477,180"}, {"time": "2.38", "coordinates": "477,182"}, {"time": "2.39", "coordinates": "476,182"}, {"time": "2.41", "coordinates": "475,184"}, {"time": "2.43", "coordinates": "473,184"}, {"time": "2.44", "coordinates": "472,184"}, {"time": "2.46", "coordinates": "471,184"}, {"time": "2.48", "coordinates": "469,184"}, {"time": "2.49", "coordinates": "467,184"}, {"time": "2.51", "coordinates": "464,184"}, {"time": "2.53", "coordinates": "462,184"}, {"time": "2.54", "coordinates": "460,185"}, {"time": "2.56", "coordinates": "459,185"}, {"time": "2.58", "coordinates": "457,186"}, {"time": "2.59", "coordinates": "456,186"}, {"time": "2.61", "coordinates": "456,187"}, {"time": "2.63", "coordinates": "454,188"}, {"time": "2.64", "coordinates": "453,188"}, {"time": "2.68", "coordinates": "452,188"}, {"time": "2.73", "coordinates": "451,189"}, {"time": "2.74", "coordinates": "449,190"}, {"time": "2.76", "coordinates": "448,190"}, {"time": "2.78", "coordinates": "447,190"}, {"time": "2.79", "coordinates": "446,190"}, {"time": "2.81", "coordinates": "445,190"}, {"time": "2.83", "coordinates": "444,190"}, {"time": "2.88", "coordinates": "444,189"}, {"time": "2.93", "coordinates": "444,188"}, {"time": "2.95", "coordinates": "444,187"}, {"time": "3.02", "coordinates": "444,186"}, {"time": "3.03", "coordinates": "444,185"}, {"time": "3.04", "coordinates": "443,185"}, {"time": "3.06", "coordinates": "442,185"}, {"time": "3.08", "coordinates": "442,184"}, {"time": "3.09", "coordinates": "441,184"}, {"time": "3.11", "coordinates": "441,183"}, {"time": "3.17", "coordinates": "440,183"}, {"time": "3.41", "coordinates": "440,182"}, {"time": "4.68", "coordinates": "441,189"}, {"time": "4.69", "coordinates": "450,212"}, {"time": "4.71", "coordinates": "456,228"}, {"time": "4.73", "coordinates": "464,246"}, {"time": "4.74", "coordinates": "466,250"}, {"time": "4.76", "coordinates": "468,254"}, {"time": "4.78", "coordinates": "470,258"}, {"time": "4.79", "coordinates": "471,260"}, {"time": "4.81", "coordinates": "472,264"}, {"time": "4.83", "coordinates": "474,271"}, {"time": "4.84", "coordinates": "475,276"}, {"time": "4.86", "coordinates": "476,279"}, {"time": "4.88", "coordinates": "476,283"}, {"time": "4.89", "coordinates": "478,285"}, {"time": "4.91", "coordinates": "479,285"}, {"time": "4.93", "coordinates": "479,287"}, {"time": "4.94", "coordinates": "480,288"}, {"time": "4.96", "coordinates": "480,290"}, {"time": "4.98", "coordinates": "480,292"}, {"time": "4.99", "coordinates": "481,296"}, {"time": "5.01", "coordinates": "482,299"}, {"time": "5.03", "coordinates": "482,300"}, {"time": "5.04", "coordinates": "484,304"}, {"time": "5.06", "coordinates": "484,305"}, {"time": "5.08", "coordinates": "484,307"}, {"time": "5.09", "coordinates": "485,311"}, {"time": "5.11", "coordinates": "486,314"}, {"time": "5.13", "coordinates": "486,316"}, {"time": "5.14", "coordinates": "487,318"}, {"time": "5.16", "coordinates": "487,319"}, {"time": "5.18", "coordinates": "487,320"}, {"time": "5.2", "coordinates": "487,321"}, {"time": "5.32", "coordinates": "487,322"}, {"time": "5.33", "coordinates": "487,323"}, {"time": "5.34", "coordinates": "488,323"}, {"time": "5.36", "coordinates": "488,324"}, {"time": "5.38", "coordinates": "489,326"}, {"time": "5.39", "coordinates": "489,327"}, {"time": "5.41", "coordinates": "491,3 ...
# File saved to C:\Users\Satish\Downloads\Survey-responses\Mouse_Movement_Output_with_num_pauses.xlsx

# %% [markdown]
# Code for data transformation

# %%
import pandas as pd
import json
from collections import Counter
data = {
    "Category": ["Genuine", "Rush", "Genuine", "Genuine", "Genuine","Rush", "Genuine", "Rush", "Rush", "Genuine", "Rush", "Genuine", "Rush", "Rush"],
    "SUB(Q1)": [
        '{"response_length": 39, "time taken": 6.47}', '{"response_length": 12, "time taken": 13.81}', '{"response_length": 7, "time taken": 13.34}', '{"response_length": 7, "time taken": 13.34}', '{"response_length": 30, "time taken": 9.95}', '{"response_length": 1, "time taken": 7.09}', '{"response_length": 26, "time taken": 7.38}', '{"response_length": 2, "time taken": 6.5}', '{"response_length": 7, "time taken": 17.93}', '{"response_length": 27, "time taken": 9.67}', '{"response_length": 11, "time taken": 6.04}'
        ,  '{"response_length": 4, "time taken": 5.29}', '{"response_length": 4, "time taken": 2.54}', '{"response_length": 0, "time taken": 6.9}'
        ],
    "MCQ(Q2)": [
        '{"responses": "b", "time taken": 19.23}', '{"responses": "a", "time taken": 20.47}', '{"responses": "a", "time taken": 24.26}', '{"responses": "a", "time taken": 24.26}', '{"responses": "c", "time taken": 21.93}', '{"responses": "a", "time taken": 8.47}', '{"responses": "e", "time taken": 15.62}', '{"responses": "a", "time taken": 7.94}', '{"responses": "e", "time taken": 22.71}', '{"responses": "b", "time taken": 26.23}', '{"responses": "b", "time taken": 10.62}'
    ,  '{"responses": "a", "time taken": 7.65}', '{"responses": "d", "time taken": 5.1}', '{"responses": "e", "time taken": 10.79}'
    ],
    "MMCQ(Q1)": [
        '{"responses": "b, c, a, d, e", "time taken": 24.93}', '{"responses": "a, c", "time taken": 31.55}', '{"responses": "d, c", "time taken": 37.27}', '{"responses": "d, c", "time taken": 37.27}', '{"responses": "a, d", "time taken": 25.18}'
    , '{"responses": "b, d", "time taken": 9.52}', '{"responses": "e, b", "time taken": 17.42}', '{"responses": "c, b", "time taken": 10.31}', '{"responses": "d, e", "time taken": 28.03}', '{"responses": "b, c", "time taken": 33.16}', '{"responses": "a, c", "time taken": 12.22}'
    ,  '{"responses": "a", "time taken": 8.7}', '{"responses": "c", "time taken": 7.24}', '{"responses": "d", "time taken": 12.17}'
    ],
    "SUB(Q2)": [
        '{"response_length": 87, "time taken": 33.51}', '{"response_length_length": 2, "time taken": 35.69}', '{"response_length_length": 48, "time taken": 461.29}', '{"response_length_length": 48, "time taken": 461.29}', '{"response_length": 39, "time taken": 32.61}'
    ,  '{"response_length": 1, "time taken": 13.12}', '{"response_length": 39, "time taken": 22.73}', '{"response_length": 2, "time taken": 14.28}', '{"response_length": 0, "time taken": 0}', '{"response_length": 41, "time taken": 41.34}', '{"response_length": 6, "time taken": 16.03}'
    , '{"response_length": 1, "time taken": 11.59}', '{"response_length": 5, "time taken": 8.33}', '{"response_length": 0, "time taken": 14.04}'
    ],
    "MCQ(Q3)": [
        '{"responses": "c", "time taken": 75.48}', '{"responses": "d", "time taken": 40.93}', '{"responses": "a", "time taken": 55.14}', '{"responses": "a", "time taken": 55.14}', '{"responses": "e", "time taken": 53.88}'
    ,  '{"responses": "", "time taken": 0}', '{"responses": "a", "time taken": 34.18}', '{"responses": "c", "time taken": 16.1}', '{"responses": "a", "time taken": 32.98}', '{"responses": "d", "time taken": 61.07}', '{"responses": "b", "time taken": 19.31}'
    ,  '{"responses": "a", "time taken": 12.51}', '{"responses": "d", "time taken": 10.35}', '{"responses": "c", "time taken": 15.35}'
    ],
    "MMCQ(Q2)": [
        '{"responses": "a", "time taken": 76.6}', '{"responses": "a, e", "time taken": 44.96}', '{"responses": "a, b, e, d, c", "time taken": 58.03}', '{"responses": "a, b, e, d, c", "time taken": 58.03}', '{"responses": "a", "time taken": 59.96}'
    ,  '{"responses": "a", "time taken": 15.29}', '{"responses": "e, b", "time taken": 37.27}', '{"responses": "d", "time taken": 19.34}', '{"responses": "e", "time taken": 36.97}', '{"responses": "a, e", "time taken": 73.12}', '{"responses": "e, d", "time taken": 21.03}'
    ,  '{"responses": "a", "time taken": 13.97}', '{"responses": "b", "time taken": 11.78}', '{"responses": "d", "time taken": 16.83}'
    ],
    "SUB(Q3)": [
        '{"response_length": 39, "time taken": 84.6}', '{"response_length": 44, "time taken": 52.35}', '{"response_length": 39, "time taken": 539.54}', '{"response_length": 39, "time taken": 539.54}', '{"response_length": 47, "time taken": 64.22}'
    ,  '{"response_length": 1, "time taken": 18.52}', '{"response_length": 39, "time taken": 42.92}', '{"response_length": 1, "time taken": 22.59}', '{"response_length": 9, "time taken": 43.16}', '{"response_length": 30, "time taken": 82.87}', '{"response_length": 16, "time taken": 27.97}' 
    ,         '{"response_length": 1, "time taken": 17.43}', '{"response_length": 4, "time taken": 13.08}', '{"response_length": 0, "time taken": 18.12}'
    ],
    "MCQ(Q4)": [
        '{"responses": "c", "time taken": 110.52}', '{"responses": "d", "time taken": 67.39}', '{"responses": "b", "time taken": 731.11}', '{"responses": "b", "time taken": 731.11}', '{"responses": "d", "time taken": 77.06}'
    ,  '{"responses": "a", "time taken": 19.63}', '{"responses": "a", "time taken": 51.76}', '{"responses": "d", "time taken": 24.47}', '{"responses": "c", "time taken": 45.91}', '{"responses": "b", "time taken": 97.63}', '{"responses": "d", "time taken": 34.77}'
    ,         '{"responses": "a", "time taken": 18.67}', '{"responses": "e", "time taken": 15.08}', '{"responses": "e", "time taken": 19.49}'
    ],
    "SUB(Q4)": [
        '{"response_length": 33, "time taken": 114.99}', '{"response_length": 13, "time taken": 72.99}', '{"response_length": 44, "time taken": 450.9}', '{"response_length": 44, "time taken": 450.9}', '{"response_length": 44, "time taken": 82.78}'
    , '{"response_length": 3, "time taken": 22.5}', '{"response_length": 25, "time taken": 57.71}', '{"response_length": 0, "time taken": 0}', '{"response_length": 0, "time taken": 0}', '{"response_length": 39, "time taken": 100.82}', '{"response_length": 11, "time taken": 40.85}'
    ,  '{"response_length": 0, "time taken": 0}', '{"response_length": 5, "time taken": 16.11}', '{"response_length": 0, "time taken": 21.76}'
    ],
    "MCQ(Q5)": [
        '{"responses": "b", "time taken": 138.23}', '{"responses": "c", "time taken": 87.49}', '{"responses": "e", "time taken": 571.59}', '{"responses": "e", "time taken": 571.59}', '{"responses": "d", "time taken": 97.5}'
    ,   '{"responses": "a", "time taken": 24.13}', '{"responses": "d", "time taken": 67.69}', '{"responses": "a", "time taken": 26.59}', '{"responses": "d", "time taken": 49.84}', '{"responses": "d", "time taken": 116.61}', '{"responses": "a", "time taken": 47.07}'
    ,  '{"responses": "a", "time taken": 20.95}', '{"responses": "b", "time taken": 20.59}', '{"responses": "c", "time taken": 23.13}'
    ],
    "MMCQ(Q3)": [
        '{"responses": "c", "time taken": 144.2}', '{"responses": "a", "time taken": 102.93}', '{"responses": "d, b", "time taken": 120.23}', '{"responses": "d, b", "time taken": 120.23}', '{"responses": "e, b", "time taken": 101.95}'
    ,   '{"responses": "a, b, c, e", "time taken": 24.91}', '{"responses": "a, c", "time taken": 72.45}', '{"responses": "a, b", "time taken": 27.77}', '{"responses": "d", "time taken": 52.12}', '{"responses": "b", "time taken": 127.4}', '{"responses": "d", "time taken": 48.6}'
    ,  '{"responses": "a, d, e", "time taken": 21.89}', '{"responses": "d", "time taken": 21.69}', '{"responses": "c", "time taken": 24.58}'
    ],
    "MCQ(Q6)": [
        '{"responses": "c", "time taken": 146.53}', '{"responses": "b", "time taken": 108.3}', '{"responses": "a", "time taken": 112.54}', '{"responses": "a", "time taken": 112.54}', '{"responses": "d", "time taken": 108.05}'
    ,  '{"responses": "a", "time taken": 28.21}', '{"responses": "e", "time taken": 78.95}', '{"responses": "d", "time taken": 30.09}', '{"responses": "c", "time taken": 56.26}', '{"responses": "d", "time taken": 136.09}', '{"responses": "e", "time taken": 51.0}'
    ,  '{"responses": "a", "time taken": 24.68}', '{"responses": "a", "time taken": 23.06}', '{"responses": "c", "time taken": 25.57}'
    ],
    "SUB(Q5)": [
        '{"response_length": 47, "time taken": 149.92}', '{"response_length": 0, "time taken": 0}', '{"response_length": 28, "time taken": 625.07}', '{"response_length": 28, "time taken": 625.07}', '{"response_length": 47, "time taken": 112.23}'
    ,  '{"response_length": 0, "time taken": 0}', '{"response_length": 47, "time taken": 83.09}', '{"response_length": 1, "time taken": 32.05}', '{"response_length": 0, "time taken": 0}', '{"response_length": 33, "time taken": 146.27}', '{"response_length": 0, "time taken": 0}'
    ,  '{"response_length": 1, "time taken": 25.11}', '{"response_length": 4, "time taken": 24.15}', '{"response_length": 0, "time taken": 27.28}' 
    ],
    "MMCQ(Q4)": [
        '{"responses": "b, a, c, e, d", "time taken": 162.32}', '{"responses": "a, b", "time taken": 116.35}', '{"responses": "b, c, d", "time taken": 97.53}', '{"responses": "b, c, d", "time taken": 97.53}', '{"responses": "a, d", "time taken": 124.97}'
    ,  '{"responses": "a", "time taken": 32.15}', '{"responses": "a, b, c, e", "time taken": 98.19}', '{"responses": "b", "time taken": 33.62}', '{"responses": "d", "time taken": 60.04}', '{"responses": "c, b", "time taken": 156.74}', '{"responses": "a", "time taken": 56.37}'
    ,  '{"responses": "a", "time taken": 27.39}', '{"responses": "d", "time taken": 26.21}', '{"responses": "e", "time taken": 28.69}'
    ],
    "MCQ(Q7)": [
        '{"responses": "a", "time taken": 168.13}', '{"responses": "a", "time taken": 123.78}', '{"responses": "b", "time taken": 91.2}', '{"responses": "b", "time taken": 91.2}', '{"responses": "d", "time taken": 134.03}'
    ,  '{"responses": "b", "time taken": 36.15}', '{"responses": "c", "time taken": 107.43}', '{"responses": "b", "time taken": 34.88}', '{"responses": "c", "time taken": 63.61}', '{"responses": "a", "time taken": 163.9}', '{"responses": "c", "time taken": 58.1}'
    , '{"responses": "d", "time taken": 31.86}', '{"responses": "a", "time taken": 27.61}', '{"responses": "d", "time taken": 29.83}'
      ],
    "SUB(Q6)": [
        '{"response_length": 2, "time taken": 172.03}', '{"response_length": 24, "time taken": 129.8}', '{"response_length": 57, "time taken": 657.35}', '{"response_length": 57, "time taken": 657.35}', '{"response_length": 31, "time taken": 139.83}'
    ,  '{"responses": "b", "time taken": 36.15}', '{"responses": "c", "time taken": 107.43}', '{"responses": "b", "time taken": 34.88}', '{"responses": "c", "time taken": 63.61}', '{"responses": "a", "time taken": 163.9}', '{"responses": "c", "time taken": 58.1}'
    ,  '{"response_length": 1, "time taken": 30.12}', '{"response_length": 5, "time taken": 28.51}', '{"response_length": 0, "time taken": 31.53}'
    ],
    "MMCQ(Q5)": [
        '{"responses": "b", "time taken": 176.82}', '{"responses": "a, d", "time taken": 143.05}', '{"responses": "e", "time taken": 75.66}', '{"responses": "e", "time taken": 75.66}', '{"responses": "a, d", "time taken": 151.14}'
    ,  '{"responses": "a", "time taken": 40.62}', '{"responses": "a, c", "time taken": 117.88}', '{"responses": "d", "time taken": 42.07}', '{"responses": "d, e", "time taken": 69.92}', '{"responses": "b", "time taken": 184.71}', '{"responses": "d", "time taken": 67.31}'
    ,  '{"responses": "a", "time taken": 33.34}', '{"responses": "c", "time taken": 30.54}', '{"responses": "e", "time taken": 33.8}'
    ],
    "MCQ(Q8)": [
        '{"responses": "c", "time taken": 178.1}', '{"responses": "b", "time taken": 147.87}', '{"responses": "a", "time taken": 71.28}', '{"responses": "a", "time taken": 71.28}', '{"responses": "c", "time taken": 158.16}'
    ,  '{"responses": "b", "time taken": 45.04}', '{"responses": "b", "time taken": 123.19}', '{"responses": "d", "time taken": 43.79}', '{"responses": "d", "time taken": 72.6}', '{"responses": "a", "time taken": 192.23}', '{"responses": "d", "time taken": 70.14}'
    ,  '{"responses": "a", "time taken": 35.43}', '{"responses": "d", "time taken": 33.24}', '{"responses": "e", "time taken": 35.36}'
    ],
    "SUB(Q7)": [
        '{"response_length": 88, "time taken": 184.83}', '{"response_length": 2, "time taken": 160.44}', '{"response_length": 2, "time taken": 717.28}', '{"response_length": 2, "time taken": 717.28}', '{"response_length": 39, "time taken": 161.39}'
    ,  '{"response_length": 10, "time taken": 46.55}', '{"response_length": 31, "time taken": 126.45}', '{"response_length": 4, "time taken": 45.67}', '{"response_length": 2, "time taken": 74.48}', '{"response_length": 22, "time taken": 196.52}', '{"response_length": 9, "time taken": 72.46}'
    ,  '{"response_length": 1, "time taken": 36.28}', '{"response_length": 3, "time taken": 34.93}', '{"response_length": 0, "time taken": 36.73}'
    ],
    "Non-attempt": [0, 1, 0, 0, 0, 2, 0, 1, 3, 0, 1, 1, 0, 0]
}
df = pd.DataFrame(data)
# Function to calculate selection pattern, unique options, most common option, and diversity score
def calc_mcq_features(columns):
    selection_patterns = []
    unique_options_list = []
    most_common_options = []
    diversity_scores = []
    
    for _, row in df.iterrows():
        all_responses = []
        for col in columns:
            try:
                response_data = json.loads(row[col])
                responses = response_data["responses"].split(", ")
                all_responses.extend(responses)
            except KeyError:
                continue
        # Calculate features
        selection_patterns.append(" -> ".join(all_responses))
        unique_options = set(all_responses)
        unique_options_list.append(len(unique_options))
        most_common_option = Counter(all_responses).most_common(1)
        most_common_options.append(most_common_option[0][0] if most_common_option else None)
        diversity_scores.append(len(unique_options) / len(all_responses) if all_responses else 0)
    
    return selection_patterns, unique_options_list, most_common_options, diversity_scores

# MCQ/MMCQ columns
mcq_cols = [col for col in df.columns if col.startswith("MCQ") or col.startswith("MMCQ")]

# Add MCQ features
df["Selection_Pattern"], df["Unique_Options"], df["Most_Common_Option"], df["Diversity_Score"] = calc_mcq_features(mcq_cols)

# Function to calculate total time for MCQ/MMCQ questions
def calc_total_time(columns):
    total_times = []
    for _, row in df.iterrows():
        total_time = 0
        for col in columns:
            try:
                response_data = json.loads(row[col])
                time_taken = response_data["time taken"]
                total_time += time_taken
            except KeyError:
                continue
        total_times.append(total_time)
    return total_times

# Add total_Time_Per_Response column
df["Total_Time_Per_Response"] = calc_total_time(mcq_cols)

# Function to calculate subjective metrics (length and time)
def calc_subjective_metrics(columns):
    total_lengths = []
    total_times = []
    for _, row in df.iterrows():
        total_length = 0
        total_time = 0
        for col in columns:
            try:
                response_data = json.loads(row[col])
                total_length += response_data.get("response_length", 0)
                total_time += response_data.get("time taken", 0)
            except KeyError:
                continue
        total_lengths.append(total_length)
        total_times.append(total_time)
    return total_lengths, total_times

# Subjective question columns
sub_cols = [col for col in df.columns if col.startswith("SUB")]

# Add Total_Sub_Length and Total_Sub_Time columns
df['Total_Sub_Length'], df['Total_Sub_Time'] = calc_subjective_metrics(sub_cols)

# Calculate Avg_Typing_Speed (length per second)
df['Avg_Typing_Speed'] = df['Total_Sub_Length'] / df['Total_Sub_Time']

# Final dataframe
final_columns = ['Category', 'Selection_Pattern', 'Unique_Options', 'Most_Common_Option',
                 'Diversity_Score', 'Total_Time_Per_Response', 'Total_Sub_Length', 
                 'Total_Sub_Time', 'Avg_Typing_Speed', 'Non-attempt']
final_df = df[final_columns]

# Display the final processed DataFrame
print(final_df)

output_file = "processed_data2.xlsx"
final_df.to_excel(output_file, index=False)

print(f"Data has been successfully saved to {output_file}")
# Out:
#    Category                                  Selection_Pattern  \
# 0   Genuine  b -> b -> c -> a -> d -> e -> c -> a -> c -> b...
# 1      Rush  a -> a -> c -> d -> a -> e -> d -> c -> a -> b...
# 2   Genuine  a -> d -> c -> a -> a -> b -> e -> d -> c -> b...
# 3   Genuine  a -> d -> c -> a -> a -> b -> e -> d -> c -> b...
# 4   Genuine  c -> a -> d -> e -> a -> d -> d -> e -> b -> d...
# 5      Rush  a -> b -> d ->  -> a -> a -> a -> a -> b -> c ...
# 6   Genuine  e -> e -> b -> a -> e -> b -> a -> d -> a -> c...
# 7      Rush  a -> c -> b -> c -> d -> d -> a -> a -> b -> d...
# 8      Rush  e -> d -> e -> a -> e -> c -> d -> d -> c -> d...
# 9   Genuine  b -> b -> c -> d -> a -> e -> b -> d -> b -> d...
# 10     Rush  b -> a -> c -> b -> e -> d -> d -> a -> d -> e...
# 11  Genuine  a -> a -> a -> a -> a -> a -> a -> d -> e -> a...
# 12     Rush  d -> c -> d -> b -> e -> b -> d -> a -> d -> a...
# 13     Rush  e -> d -> c -> d -> e -> c -> c -> c -> e -> d...
#
#     Unique_Options Most_Common_Option  Diversity_Score  \
# 0                5                  c         0.250000
# 1                5                  a         0.312500
# 2                5                  a         0.250000
# 3                5                  a         0.250000
# 4                5                  d         0.312500
# 5                6                  a         0.375000
# 6                5                  e         0.263158
# 7                4                  d         0.285714
# 8                4                  d         0.285714
# 9                5                  b         0.333333
# 10               5                  d         0.357143
# 11               3                  a         0.214286
# 12               5                  d         0.416667
# 13               3                  e         0.250000
#
#     Total_Time_Per_Response  Total_Sub_Length  Total_Sub_Time  \
# 0                   1421.09               335          746.35
# 1                   1035.07                95          465.08
# 2                   2045.84               177         3464.77
# 3                   2045.84               177         3464.77
# 4                   1113.81               277          603.01
# 5                    284.12                16          143.93
# 6                    822.03               207          447.71
# 7                    316.97                10          155.97
# 8                    590.99                18          199.18
# 9                   1368.89               192          741.39
# 10                   496.54                53          221.45
# 11                   257.04                 9          125.82
# 12                   232.49                30          127.65
# 13                   275.59                 0          156.36
#
#     Avg_Typing_Speed  Non-attempt
# 0           0.448851            0
# 1           0.204266            1
# 2           0.051086            0
# 3           0.051086            0
# 4           0.459362            0
# 5           0.111165            2
# 6           0.462353            0
# 7           0.064115            1
# 8           0.090371            3
# 9           0.258973            0
# 10          0.239332            1
# 11          0.071531            1
# 12          0.235018            0
# 13          0.000000            0
# Data has been successfully saved to processed_data2.xlsx

# %% [markdown]
# CALLING THE DATASET

# %%
import pandas as pd

# Load the dataset from the specified path
file_path = r"C:\Users\Satish\Downloads\Survey-responses\result\adjusted_dataset.csv"
data = pd.read_csv(file_path)

# Preview the dataset
print(data.head())
# Out:
#   Category                                  Selection_Pattern  Unique_Options  \
# 0  Genuine  b -> b -> c -> a -> d -> e -> c -> a -> c -> b...               5
# 1     Rush  a -> a -> c -> d -> a -> e -> d -> c -> a -> b...               5
# 2  Genuine  a -> d -> c -> a -> a -> b -> e -> d -> c -> b...               5
# 3  Genuine  a -> d -> c -> a -> a -> b -> e -> d -> c -> b...               5
# 4  Genuine  c -> a -> d -> e -> a -> d -> d -> e -> b -> d...               5
#
#   Most_Common_Option  Diversity_Score  Total_Time_Per_Response  \
# 0                  c           0.2500                     1421
# 1                  a           0.3125                     1035
# 2                  a           0.2500                     2045
# 3                  a           0.2500                     2045
# 4                  d           0.3125                     1113
#
#    Total_Sub_Length  Total_Sub_Time  Avg_Typing_Speed  Non-attempt
# 0            746.35        0.448851          0.448851            0
# 1            465.08        0.204266          0.204266            1
# 2           3464.77        0.051086          0.051086            0
# 3           3464.77        0.051086          0.051086            0
# 4            603.01        0.459362          0.459362            0

# %% [markdown]
# preprocessing for GBT

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# Define features and target
X = data.drop('Category', axis=1)  # Drop the target column
y = data['Category']  # Target column

# Encode the target variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Convert non-numeric columns to numeric using one-hot encoding
X_encoded = pd.get_dummies(X, drop_first=True)
# Train-test split (keeping 20% of the data for test sets)
X_train, X_test_temp, y_train, y_test_temp = train_test_split(X_encoded, y_encoded, test_size=0.2, random_state=42)

# Split the test set into two halves
X_test_1, X_test_2, y_test_1, y_test_2 = train_test_split(X_test_temp, y_test_temp, test_size=0.5, random_state=42)

# %% [markdown]
# training the GBT

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report

# Initialize the GBT model
gbt_model = XGBClassifier(random_state=42, use_label_encoder=False, eval_metric="mlogloss")

# Train the model using preprocessed training data
gbt_model.fit(X_train, y_train)

# Evaluate the model on both test splits
y_pred_test_1 = gbt_model.predict(X_test_1)
y_pred_test_2 = gbt_model.predict(X_test_2)

# Evaluate performance
print("GBT Model Performance:")
print("Test 1 Accuracy:", accuracy_score(y_test_1, y_pred_test_1))
print("Test 2 Accuracy:", accuracy_score(y_test_2, y_pred_test_2))
print("\nClassification Report (Test 1):")
print(classification_report(y_test_1, y_pred_test_1))
print("\nClassification Report (Test 2):")
print(classification_report(y_test_2, y_pred_test_2))
# Out:
# GBT Model Performance:
# Test 1 Accuracy: 0.6
# Test 2 Accuracy: 0.4
#
# Classification Report (Test 1):
#               precision    recall  f1-score   support
#
#            0       0.75      0.50      0.60        12
#            1       0.50      0.75      0.60         8
#
#     accuracy                           0.60        20
#    macro avg       0.62      0.62      0.60        20
# weighted avg       0.65      0.60      0.60        20
#
#
# Classification Report (Test 2):
#               precision    recall  f1-score   support
#
#            0       0.64      0.47      0.54        15
#            1       0.11      0.20      0.14         5
#
#     accuracy                           0.40        20
#    macro avg       0.37      0.33      0.34        20
# weighted avg       0.51      0.40      0.44        20
# C:\Users\Satish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\xgboost\core.py:158: UserWarning: [21:51:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
